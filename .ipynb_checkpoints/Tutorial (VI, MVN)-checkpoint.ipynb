# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from scipy.special import comb

import jax
import jax.numpy as jnp
from jax.experimental.ode import odeint
from jax import vmap, jit, jacfwd, jacrev
from jax.nn import softplus, relu

np.random.seed(123)

# %% [markdown]
# Let $x(t)$ represent a vector of $n_x$ time dependent variables. We'll use an ordinary differential equation (ODE) model to characterize the rate of change of the variables,
#
# $$
# \frac{d x(t)}{d t} = f(x(t), w)
# $$
# where $w$ is a vector of $n_w$ learnable parameters.
#
# Model estimates of $x(t)$ are computed by integrating the ODE,
#
# $$
# y(t, x_0, w) = x_0 + \int_0^t f(x(t), w) d t
# $$
#
# Model estimates of $x(t)$ are denoted as $y(t, x_0, w)$ and measuremed values are denoted as $y(t)$.

# %% [markdown]
# Ground truth ODE model

# %%
# growth rate
r = .75

# carrying capacity
k = .75
    
def dxdt(x, t):
    
    # rate of change
    dxdt = x * r * (1. - x/k)
    
    return dxdt

# %%
# initial condition
x0 = .1

# time frame 
t_span = np.linspace(0, 10, 50)

# simulate data
y_mean = odeint(dxdt, x0, t_span)

# sparsely sampled 
t_sparse = np.linspace(0, 10, 5)
y_sparse = odeint(dxdt, x0, t_sparse)

# %%
# plot data
plt.figure(figsize=(8, 3))
plt.subplot(1, 2, 1)
plt.plot(t_span, y_mean, linestyle='--', c='k', alpha=.7)
plt.scatter(t_span, y_mean + .01 * np.random.randn(len(y_mean)))
plt.title('low data uncertainty')
# plt.ylim([0, 1.5])
plt.xlabel("time")
plt.ylabel('y(t)')

plt.subplot(1, 2, 2)
plt.plot(t_span, y_mean, linestyle='--', c='k', alpha=.7)
plt.scatter(t_span, y_mean + .1 * np.random.randn(len(y_mean)))
plt.title('high data uncertainty')
# plt.ylim([0, 1.5])
plt.xlabel("time")
plt.show()

# %% [markdown]
# The distribution of the data conditioned on the input is important to characterize correctly and is used to define the likelihood function.
#
# In this case, the data distribution is Gaussian with mean $y(x_0, t, w)$ and variance $\beta^2$.
#
# $$
# p(y(t) | x_0, t, w, \beta) = \mathcal{N}(y(t) | y(x_0, t, w), \beta^2)
# $$

# %% [markdown]
# Variational Inference
#
# Goal of variational inference is to minimize the Kullback-Leibler divergence between an approximate posterior distribution and the true parameter posterior distribution.
#
# The true parameter distribution is given by Bayes' theorem as proportional to the product of the likelihood and the prior on parameters.
#
# With a data set denoted as $D = \{y(t_1), ..., y(t_N)\}$, the likelihood captures data uncertainty,
#
# $$
# p(D | w, \beta) = \prod_{i=1}^N \mathcal{N}(y(t_i) | y(x_0, t_i, w), \beta^2)
# $$
#
# A zero-mean Gaussian prior distribution promotes simplicity in the model,
#
# $$
# p(w_j) = \mathcal{N}(w_j | 0, \alpha_j)
# $$
#
# The postrior distribution is
#
# $$
# p(w | D, \alpha, \beta) = \frac{p(D | w, \beta) p(w)}{p(D|\alpha, \beta)}
# $$
#
# $$
# p(w | D, \alpha, \beta) = \frac{\prod_{i=1}^N \mathcal{N}(y(t_i) | y(x_0, t_i, w), \beta^2) \prod_{j=1}^{n_w} \mathcal{N}(w_j | 0, \alpha_j)}{p(D|\alpha, \beta)}
# $$
#
# The goal of variational inference is to approximate this distribution using a parametric distribution, $q(w | \theta)$. Optimization of $\theta$ is performed by minimizing the Kullback-Leibler divergence with the true posterior,
#
# $$
# \theta^* = \text{arg} \; \underset{\theta}{\text{min}} \;
# \text{KL} \left[ q(w | \theta) || p(w | D, \alpha, \beta) \right]
# $$
#
# where
#
# $$
# \text{KL} \left[ q(w | \theta) || p(w | D, \alpha, \beta) \right] =
# -\int_w q(w | \theta) \mathrm{ln} \frac{p(w | D, \alpha, \beta)}{q(w | \theta)} d w
# $$
#
# $$
# = -\int_w q(w | \theta) \mathrm{ln} p(w | D, \alpha, \beta) d w + \int_w q(w | \theta) \mathrm{ln} q(w | \theta) d w
# $$
#
# To enable a flexible class of approximating distributions, we'll use the change of variables formula to transform samples from a distribution that's easy to sample from,
#
# $$
# w = T(z, \theta), \quad z_j \sim \mathcal{N}(z_j | 0, 1)
# $$
#
# The change of variables formula gives,
#
# $$
# q(w | \theta) = p(z) \cdot | \mathrm{det} \nabla_{z} T(z, \theta) |^{-1}
# $$
#
# and
#
# $$
# \mathrm{ln} q(w|\theta) = \mathrm{ln} p(z) - \mathrm{ln} | \mathrm{det}
# \nabla_{z} T(z, \theta)|
# $$
#
# We can use a Monte Carlo estimate of the $KL$ divergence, where each $z_i^k \sim \mathcal{N}(0, 1)$,
#
# $$
# \text{KL} \left[ q(w | \theta) || p(w | D, \alpha, \beta) \right] \approx
# \frac{1}{K} \sum_{k=1}^K -\mathrm{ln} p(T(z^k, \theta) | D, \alpha, \beta) - \mathrm{ln} | \mathrm{det}
# \nabla_{z} T(z^k, \theta)|
# $$
#
# $$
# =\frac{1}{K} \sum_{k=1}^K \left( \sum_{i=1}^N -\mathrm{ln} \mathcal{N}(y(t_i) | y(x_0, t_i, T(z^k, \theta)), \beta^2) - \sum_{j=1}^{n_w} \mathrm{ln}\mathcal{N}(T_j(z^k, \theta) | 0, \alpha_j) -\mathrm{ln} | \mathrm{det}
# \nabla_{z} T(z^k, \theta)| \right)
# $$
#
# Keeping only terms that depend on $\theta$, we'll define the objective function
# $$
# J(\theta) =\frac{1}{K} \sum_{k=1}^K \left( \sum_{i=1}^N \frac{(y(t_i) - y(x_0, t_i, T(z^k, \theta))^2}{2 \beta^2} + \sum_{j=1}^{n_w} \frac{T_j^2(z^k, \theta)}{2 \alpha_j^2} - \mathrm{ln} | \mathrm{det}
# \nabla_{z} T(z^k, \theta)| \right)
# $$

# %%
# function to transform latent variables
@jit
def T(z, theta): 
    
    # unpack variational parameters 
    m, s = theta
    
    # Cholesky of multivariate Gaussian distribution 
    tril_indices = jnp.tril_indices(len(m))
    L = jnp.zeros([len(m), len(m)])
    L = L.at[tril_indices].set(s)
    
    # sample from MV Gaussian 
    w = m + L@z 
    
    return w

# general function to compute log of absolute determinant 
def log_abs_det_T(z, theta):
    
    # Jacobian w.r.t. z 
    jac = jacfwd(T)(z, theta)
    
    # return log abs det 
    return jnp.log(jnp.abs(jnp.linalg.det(jac)))

# negative log likelihood component of KL divergence 
def neg_log_likelihood(y, x0, t, w, beta):
    
    # model predictions 
    y_hat = model(x0, t, w)
    
    # return squared error 
    return (y - y_hat) ** 2 / beta ** 2 / 2.

# negative log of prior 
def neg_log_prior(w, alpha):
    
    # return sum of squares
    return jnp.sum(w ** 2 / alpha ** 2) / 2. 

# overall per sample cost function 
@jit
def J(theta, z, y, x0, t, alpha, beta, N):
    
    # random sample
    w = T(z, theta)
    
    # negative log likelihood
    nll = neg_log_likelihood(y, x0, t, w, beta)
    
    # negative log prior
    nlp = neg_log_prior(w, alpha) / N 
    
    # posterior entropy
    lad = log_abs_det_T(w, theta) / N 
    
    return nll + nlp - lad 

# gradient of cost w.r.t. theta  
J_grad = jit(jacrev(J))

# %%
def adam(loss, grad, data, theta, hyperparams, n_sample=1, n_epochs=100, lr=1e-3, beta1=.9, beta2=.999, epsilon=1e-8):
    
    # unpack data set
    y, x0, t = data
    N = len(y)
    order = np.arange(N)
    
    # unpack hyperparameters
    alpha, beta, = hyperparams
    
    # init params 
    c = 0
    m = []
    v = []
    for theta_i in theta:
        m.append(np.zeros_like(theta_i))
        v.append(np.zeros_like(theta_i))
    
    # loop over epochs
    for epoch in range(n_epochs):
    
        # sgd over each sample
        np.random.shuffle(order)
        epoch_loss = 0.
        for idx in order:
            
            # estimate gradient 
            grads = []
            for theta_i in theta:
                grads.append(0.)
            for _ in range(n_sample):
                
                # random sample
                z = np.random.randn(M)
                
                # evaluate gradient
                gradient = grad(theta, 
                                z, 
                                y[idx], 
                                x0[idx], 
                                t[idx], 
                                alpha, beta, N) 
                
                # average gradients over samples 
                for i, grad_i in enumerate(gradient):
                    grads[i] += np.nan_to_num(grad_i) / n_sample
                
                # evaluate loss
                epoch_loss += np.nan_to_num(loss(theta, 
                                                 z, 
                                                 y[idx], 
                                                 x0[idx], 
                                                 t[idx], 
                                                 alpha, beta, N)) / n_sample

            # moment estimation
            c += 1   
            for i, grad_i in enumerate(grads):
                m[i] = beta1 * m[i] + (1. - beta1) * grad_i
                v[i] = beta2 * v[i] + (1. - beta2) * (grad_i ** 2)

                # adjust moments based on number of iterations
                m_hat = m[i] / (1. - beta1 ** c)
                v_hat = v[i] / (1. - beta2 ** c)

                # take step
                theta[i] -= lr * m_hat / (np.sqrt(v_hat) + epsilon)
                
        print(f"Epoch {epoch+1:.0f}, Loss {epoch_loss:.5f}")
        
    # return params
    return theta

# %% [markdown]
# Define model to fit

# %%
# rate of change of model
def dmdt(x, t, w):
    
    # unpack model parameters
    r, k = w
    
    # rate of change
    dxdt = x * r * (1. - x/k)
    
    return dxdt 

# model integrates ode up to time t 
def model(x0, t, w):
    
    # integrate dmdt from x0 to xt 
    return odeint(dmdt, x0, jnp.linspace(0, t), w)[-1]

# model integrates ode up to time t 
def model_tspan(x0, tspan, w):
    
    # integrate dmdt from x0 to xt 
    return odeint(dmdt, x0, tspan, w)

# %%
# params 
alpha = 10.
beta = .075
M = 2

# data set
x0 = .1
t = np.linspace(0., 10., 8)
y = odeint(dxdt, x0, t) + beta * np.append(0., np.random.randn(len(t)-1))
D = (y[1:], [x0]*len(y[1:]), t[1:])

# init params
mu = jnp.ones(M)
M2 = M + int(comb(M, 2))
s = jnp.ones(M2)/5.
theta = [mu, s]

# %%
theta = adam(J, J_grad, D, theta, 
             hyperparams=(alpha, beta), 
             lr=1e-3, n_sample=5, n_epochs=1000)
# Out:
# Epoch 1, Loss 85.37641
# Epoch 2, Loss 54.20756
# Epoch 3, Loss 71.31056
# Epoch 4, Loss 53.05735
# Epoch 5, Loss 66.06573
# Epoch 6, Loss 84.04373
# Epoch 7, Loss 74.12124
# Epoch 8, Loss 73.96788
# Epoch 9, Loss 66.17791
# Epoch 10, Loss 32.31818
# Epoch 11, Loss 46.94791
# Epoch 12, Loss 41.28884
# Epoch 13, Loss 37.20656
# Epoch 14, Loss 38.67243
# Epoch 15, Loss 51.12114
# Epoch 16, Loss 44.98474
# Epoch 17, Loss 17.85644
# Epoch 18, Loss 41.05434
# Epoch 19, Loss 33.86136
# Epoch 20, Loss 40.17508
# Epoch 21, Loss 22.06814
# Epoch 22, Loss 33.06286
# Epoch 23, Loss 23.51064
# Epoch 24, Loss 46.85618
# Epoch 25, Loss 29.26692
# Epoch 26, Loss 31.87387
# Epoch 27, Loss 28.30640
# Epoch 28, Loss 32.57805
# Epoch 29, Loss 25.45085
# Epoch 30, Loss 25.91066
# Epoch 31, Loss 21.99650
# Epoch 32, Loss 21.21003
# Epoch 33, Loss 18.15481
# Epoch 34, Loss 28.33855
# Epoch 35, Loss 15.86407
# Epoch 36, Loss 20.98811
# Epoch 37, Loss 17.99813
# Epoch 38, Loss 19.08348
# Epoch 39, Loss 17.63944
# Epoch 40, Loss 23.18823
# Epoch 41, Loss 21.38737
# Epoch 42, Loss 20.42137
# Epoch 43, Loss 17.60638
# Epoch 44, Loss 16.58226
# Epoch 45, Loss 17.38345
# Epoch 46, Loss 19.44835
# Epoch 47, Loss 18.76182
# Epoch 48, Loss 12.62592
# Epoch 49, Loss 13.90715
# Epoch 50, Loss 13.59833
# Epoch 51, Loss 12.01745
# Epoch 52, Loss 12.82279
# Epoch 53, Loss 18.97691
# Epoch 54, Loss 13.39827
# Epoch 55, Loss 15.68677
# Epoch 56, Loss 16.80656
# Epoch 57, Loss 13.10073
# Epoch 58, Loss 12.76215
# Epoch 59, Loss 12.40624
# Epoch 60, Loss 11.64201
# Epoch 61, Loss 14.16288
# Epoch 62, Loss 13.64240
# Epoch 63, Loss 12.59206
# Epoch 64, Loss 11.78950
# Epoch 65, Loss 14.49923
# Epoch 66, Loss 12.70408
# Epoch 67, Loss 13.21237
# Epoch 68, Loss 13.17315
# Epoch 69, Loss 12.22628
# Epoch 70, Loss 12.68874
# Epoch 71, Loss 12.91036
# Epoch 72, Loss 11.40720
# Epoch 73, Loss 13.58956
# Epoch 74, Loss 12.66320
# Epoch 75, Loss 12.92133
# Epoch 76, Loss 12.65155
# Epoch 77, Loss 12.25197
# Epoch 78, Loss 13.22059
# Epoch 79, Loss 11.68843
# Epoch 80, Loss 13.99058
# Epoch 81, Loss 12.57226
# Epoch 82, Loss 12.22631
# Epoch 83, Loss 12.65610
# Epoch 84, Loss 13.66822
# Epoch 85, Loss 13.76356
# Epoch 86, Loss 13.97183
# Epoch 87, Loss 11.49128
# Epoch 88, Loss 11.78159
# Epoch 89, Loss 11.42213
# Epoch 90, Loss 12.90644
# Epoch 91, Loss 12.88722
# Epoch 92, Loss 13.15648
# Epoch 93, Loss 11.86147
# Epoch 94, Loss 11.49686
# Epoch 95, Loss 11.66942
# Epoch 96, Loss 12.22826
# Epoch 97, Loss 11.28963
# Epoch 98, Loss 10.71078
# Epoch 99, Loss 11.53905
# Epoch 100, Loss 12.52170
# Epoch 101, Loss 13.30349
# Epoch 102, Loss 13.11627
# Epoch 103, Loss 11.90619
# Epoch 104, Loss 12.30329
# Epoch 105, Loss 11.69606
# Epoch 106, Loss 12.78051
# Epoch 107, Loss 11.87208
# Epoch 108, Loss 13.41796
# Epoch 109, Loss 12.21944
# Epoch 110, Loss 11.10686
# Epoch 111, Loss 11.58340
# Epoch 112, Loss 11.68662
# Epoch 113, Loss 12.14034
# Epoch 114, Loss 12.66673
# Epoch 115, Loss 13.07115
# Epoch 116, Loss 13.75565
# Epoch 117, Loss 12.75993
# Epoch 118, Loss 12.53061
# Epoch 119, Loss 11.54709
# Epoch 120, Loss 12.16559
# Epoch 121, Loss 13.79172
# Epoch 122, Loss 11.34660
# Epoch 123, Loss 12.40253
# Epoch 124, Loss 10.98674
# Epoch 125, Loss 11.43203
# Epoch 126, Loss 11.33359
# Epoch 127, Loss 14.38543
# Epoch 128, Loss 13.01297
# Epoch 129, Loss 11.16631
# Epoch 130, Loss 12.19407
# Epoch 131, Loss 11.79225
# Epoch 132, Loss 12.10490
# Epoch 133, Loss 12.00950
# Epoch 134, Loss 11.95636
# Epoch 135, Loss 12.05141
# Epoch 136, Loss 12.08041
# Epoch 137, Loss 12.42564
# Epoch 138, Loss 12.10285
# Epoch 139, Loss 11.32292
# Epoch 140, Loss 12.82936
# Epoch 141, Loss 12.51862
# Epoch 142, Loss 11.04976
# Epoch 143, Loss 11.94366
# Epoch 144, Loss 11.31142
# Epoch 145, Loss 10.52714
# Epoch 146, Loss 13.00539
# Epoch 147, Loss 12.08843
# Epoch 148, Loss 11.85449
# Epoch 149, Loss 14.18105
# Epoch 150, Loss 13.11936
# Epoch 151, Loss 10.78507
# Epoch 152, Loss 11.13918
# Epoch 153, Loss 13.69701
# Epoch 154, Loss 12.30754
# Epoch 155, Loss 11.75918
# Epoch 156, Loss 11.74039
# Epoch 157, Loss 12.46950
# Epoch 158, Loss 12.47276
# Epoch 159, Loss 12.04151
# Epoch 160, Loss 11.29416
# Epoch 161, Loss 12.57258
# Epoch 162, Loss 12.90897
# Epoch 163, Loss 11.34161
# Epoch 164, Loss 11.38384
# Epoch 165, Loss 12.24869
# Epoch 166, Loss 10.42815
# Epoch 167, Loss 12.09642
# Epoch 168, Loss 10.93913
# Epoch 169, Loss 12.31095
# Epoch 170, Loss 11.50407
# Epoch 171, Loss 11.38970
# Epoch 172, Loss 12.57839
# Epoch 173, Loss 10.62893
# Epoch 174, Loss 12.15997
# Epoch 175, Loss 11.70865
# Epoch 176, Loss 11.10740
# Epoch 177, Loss 12.68044
# Epoch 178, Loss 12.54859
# Epoch 179, Loss 11.12628
# Epoch 180, Loss 11.42432
# Epoch 181, Loss 11.34085
# Epoch 182, Loss 10.18307
# Epoch 183, Loss 12.64989
# Epoch 184, Loss 14.02824
# Epoch 185, Loss 12.81159
# Epoch 186, Loss 11.41749
# Epoch 187, Loss 12.42960
# Epoch 188, Loss 11.38801
# Epoch 189, Loss 12.29396
# Epoch 190, Loss 12.39485
# Epoch 191, Loss 11.11678
# Epoch 192, Loss 11.25921
# Epoch 193, Loss 12.10251
# Epoch 194, Loss 10.82162
# Epoch 195, Loss 10.58593
# Epoch 196, Loss 11.99582
# Epoch 197, Loss 11.08004
# Epoch 198, Loss 10.19964
# Epoch 199, Loss 11.43011
# Epoch 200, Loss 11.19787
# Epoch 201, Loss 12.24024
# Epoch 202, Loss 12.63092
# Epoch 203, Loss 11.11801
# Epoch 204, Loss 12.45030
# Epoch 205, Loss 13.38469
# Epoch 206, Loss 10.74527
# Epoch 207, Loss 11.45940
# Epoch 208, Loss 11.95625
# Epoch 209, Loss 13.52495
# Epoch 210, Loss 11.60327
# Epoch 211, Loss 11.32240
# Epoch 212, Loss 11.51171
# Epoch 213, Loss 13.26782
# Epoch 214, Loss 10.43779
# Epoch 215, Loss 11.72125
# Epoch 216, Loss 13.25620
# Epoch 217, Loss 12.76674
# Epoch 218, Loss 11.02682
# Epoch 219, Loss 12.26125
# Epoch 220, Loss 11.50865
# Epoch 221, Loss 12.39115
# Epoch 222, Loss 10.92296
# Epoch 223, Loss 11.76892
# Epoch 224, Loss 13.97149
# Epoch 225, Loss 11.02119
# Epoch 226, Loss 11.86933
# Epoch 227, Loss 12.47233
# Epoch 228, Loss 11.89829
# Epoch 229, Loss 11.18537
# Epoch 230, Loss 12.51480
# Epoch 231, Loss 11.94096
# Epoch 232, Loss 12.16246
# Epoch 233, Loss 12.14029
# Epoch 234, Loss 11.16762
# Epoch 235, Loss 12.00329
# Epoch 236, Loss 12.19659
# Epoch 237, Loss 12.00221
# Epoch 238, Loss 11.62832
# Epoch 239, Loss 13.22531
# Epoch 240, Loss 11.37921
# Epoch 241, Loss 11.66957
# Epoch 242, Loss 11.36834
# Epoch 243, Loss 12.01610
# Epoch 244, Loss 11.81392
# Epoch 245, Loss 11.80869
# Epoch 246, Loss 11.88421
# Epoch 247, Loss 11.84033
# Epoch 248, Loss 10.33951
# Epoch 249, Loss 12.98458
# Epoch 250, Loss 10.96429
# Epoch 251, Loss 12.06547
# Epoch 252, Loss 12.33774
# Epoch 253, Loss 11.50627
# Epoch 254, Loss 12.76456
# Epoch 255, Loss 12.02093
# Epoch 256, Loss 13.26004
# Epoch 257, Loss 12.61235
# Epoch 258, Loss 10.96049
# Epoch 259, Loss 11.41163
# Epoch 260, Loss 11.19694
# Epoch 261, Loss 12.11995
# Epoch 262, Loss 12.78467
# Epoch 263, Loss 12.47240
# Epoch 264, Loss 13.21450
# Epoch 265, Loss 11.52656
# Epoch 266, Loss 12.26481
# Epoch 267, Loss 11.52268
# Epoch 268, Loss 11.98588
# Epoch 269, Loss 11.22599
# Epoch 270, Loss 10.61486
# Epoch 271, Loss 12.52009
# Epoch 272, Loss 11.93991
# Epoch 273, Loss 12.14488
# Epoch 274, Loss 11.99345
# Epoch 275, Loss 12.19627
# Epoch 276, Loss 11.76903
# Epoch 277, Loss 11.31631
# Epoch 278, Loss 11.84571
# Epoch 279, Loss 11.55074
# Epoch 280, Loss 11.51023
# Epoch 281, Loss 12.63589
# Epoch 282, Loss 10.75537
# Epoch 283, Loss 11.02239
# Epoch 284, Loss 11.91276
# Epoch 285, Loss 11.84097
# Epoch 286, Loss 13.05481
# Epoch 287, Loss 12.68813
# Epoch 288, Loss 11.11206
# Epoch 289, Loss 12.09951
# Epoch 290, Loss 11.60477
# Epoch 291, Loss 11.50591
# Epoch 292, Loss 12.49019
# Epoch 293, Loss 14.22397
# Epoch 294, Loss 11.74266
# Epoch 295, Loss 11.51810
# Epoch 296, Loss 11.39124
# Epoch 297, Loss 12.46322
# Epoch 298, Loss 10.68320
# Epoch 299, Loss 12.76582
# Epoch 300, Loss 10.96245
# Epoch 301, Loss 10.91336
# Epoch 302, Loss 11.62292
# Epoch 303, Loss 11.66863
# Epoch 304, Loss 12.55948
# Epoch 305, Loss 12.96782
# Epoch 306, Loss 11.70663
# Epoch 307, Loss 11.26464
# Epoch 308, Loss 11.32532
# Epoch 309, Loss 12.14707
# Epoch 310, Loss 12.68110
# Epoch 311, Loss 12.43687
# Epoch 312, Loss 11.80597
# Epoch 313, Loss 11.85293
# Epoch 314, Loss 15.02299
# Epoch 315, Loss 12.72003
# Epoch 316, Loss 11.11972
# Epoch 317, Loss 11.41962
# Epoch 318, Loss 12.43803
# Epoch 319, Loss 11.12612
# Epoch 320, Loss 12.89360
# Epoch 321, Loss 11.12162
# Epoch 322, Loss 12.09505
# Epoch 323, Loss 11.49939
# Epoch 324, Loss 14.10141
# Epoch 325, Loss 11.59282
# Epoch 326, Loss 13.24456
# Epoch 327, Loss 11.82732
# Epoch 328, Loss 11.89486
# Epoch 329, Loss 11.80831
# Epoch 330, Loss 12.40154
# Epoch 331, Loss 14.58025
# Epoch 332, Loss 11.47366
# Epoch 333, Loss 11.89101
# Epoch 334, Loss 10.92167
# Epoch 335, Loss 13.32823
# Epoch 336, Loss 11.76499
# Epoch 337, Loss 11.91434
# Epoch 338, Loss 11.78732
# Epoch 339, Loss 11.68715
# Epoch 340, Loss 12.85841
# Epoch 341, Loss 11.32789
# Epoch 342, Loss 11.16789
# Epoch 343, Loss 11.59854
# Epoch 344, Loss 10.84448
# Epoch 345, Loss 11.98757
# Epoch 346, Loss 12.73319
# Epoch 347, Loss 12.50993
# Epoch 348, Loss 11.68238
# Epoch 349, Loss 11.49961
# Epoch 350, Loss 13.79607
# Epoch 351, Loss 11.39587
# Epoch 352, Loss 12.32195
# Epoch 353, Loss 12.19017
# Epoch 354, Loss 10.67543
# Epoch 355, Loss 12.40372
# Epoch 356, Loss 12.04951
# Epoch 357, Loss 13.06490
# Epoch 358, Loss 13.30713
# Epoch 359, Loss 11.96744
# Epoch 360, Loss 10.00830
# Epoch 361, Loss 11.64127
# Epoch 362, Loss 11.74589
# Epoch 363, Loss 12.74434
# Epoch 364, Loss 12.67685
# Epoch 365, Loss 12.58402
# Epoch 366, Loss 11.04854
# Epoch 367, Loss 12.21863
# Epoch 368, Loss 12.98702
# Epoch 369, Loss 13.11606
# Epoch 370, Loss 11.45041
# Epoch 371, Loss 10.63789
# Epoch 372, Loss 12.87495
# Epoch 373, Loss 11.98556
# Epoch 374, Loss 11.50628
# Epoch 375, Loss 13.21960
# Epoch 376, Loss 11.61577
# Epoch 377, Loss 11.01800
# Epoch 378, Loss 10.58047
# Epoch 379, Loss 11.70944
# Epoch 380, Loss 11.69139
# Epoch 381, Loss 11.90856
# Epoch 382, Loss 10.81670
# Epoch 383, Loss 11.35573
# Epoch 384, Loss 12.90588
# Epoch 385, Loss 12.74390
# Epoch 386, Loss 11.43203
# Epoch 387, Loss 10.70360
# Epoch 388, Loss 13.05092
# Epoch 389, Loss 11.28167
# Epoch 390, Loss 11.79170
# Epoch 391, Loss 13.14841
# Epoch 392, Loss 10.61882
# Epoch 393, Loss 12.18616
# Epoch 394, Loss 12.34791
# Epoch 395, Loss 13.00443
# Epoch 396, Loss 12.32317
# Epoch 397, Loss 12.32906
# Epoch 398, Loss 12.15167
# Epoch 399, Loss 13.38120
# Epoch 400, Loss 11.75192
# Epoch 401, Loss 11.88779
# Epoch 402, Loss 13.36730
# Epoch 403, Loss 12.44838
# Epoch 404, Loss 12.05135
# Epoch 405, Loss 11.99662
# Epoch 406, Loss 11.91688
# Epoch 407, Loss 12.31270
# Epoch 408, Loss 13.10213
# Epoch 409, Loss 11.35764
# Epoch 410, Loss 12.31367
# Epoch 411, Loss 12.44483
# Epoch 412, Loss 10.94876
# Epoch 413, Loss 12.39042
# Epoch 414, Loss 11.23637
# Epoch 415, Loss 11.86511
# Epoch 416, Loss 12.30226
# Epoch 417, Loss 10.56116
# Epoch 418, Loss 11.59360
# Epoch 419, Loss 11.54814
# Epoch 420, Loss 13.39864
# Epoch 421, Loss 11.86770
# Epoch 422, Loss 10.75271
# Epoch 423, Loss 10.52527
# Epoch 424, Loss 11.22918
# Epoch 425, Loss 13.03218
# Epoch 426, Loss 13.13226
# Epoch 427, Loss 11.23422
# Epoch 428, Loss 12.91860
# Epoch 429, Loss 13.45606
# Epoch 430, Loss 12.12135
# Epoch 431, Loss 11.49105
# Epoch 432, Loss 11.24145
# Epoch 433, Loss 12.00652
# Epoch 434, Loss 11.38537
# Epoch 435, Loss 11.80093
# Epoch 436, Loss 11.03705
# Epoch 437, Loss 12.79929
# Epoch 438, Loss 14.24500
# Epoch 439, Loss 12.48907
# Epoch 440, Loss 12.69902
# Epoch 441, Loss 12.21400
# Epoch 442, Loss 12.35510
# Epoch 443, Loss 12.22916
# Epoch 444, Loss 11.88422
# Epoch 445, Loss 12.73022
# Epoch 446, Loss 12.24761
# Epoch 447, Loss 12.44280
# Epoch 448, Loss 11.87804
# Epoch 449, Loss 11.40841
# Epoch 450, Loss 11.89071
# Epoch 451, Loss 13.33418
# Epoch 452, Loss 12.11831
# Epoch 453, Loss 10.98393
# Epoch 454, Loss 13.32028
# Epoch 455, Loss 11.75744
# Epoch 456, Loss 11.68533
# Epoch 457, Loss 11.51443
# Epoch 458, Loss 12.74755
# Epoch 459, Loss 11.14855
# Epoch 460, Loss 11.84945
# Epoch 461, Loss 12.42371
# Epoch 462, Loss 11.50790
# Epoch 463, Loss 12.96658
# Epoch 464, Loss 12.96035
# Epoch 465, Loss 11.59485
# Epoch 466, Loss 12.07710
# Epoch 467, Loss 11.35264
# Epoch 468, Loss 11.29288
# Epoch 469, Loss 11.23172
# Epoch 470, Loss 11.88135
# Epoch 471, Loss 10.48632
# Epoch 472, Loss 12.21844
# Epoch 473, Loss 10.97169
# Epoch 474, Loss 11.59893
# Epoch 475, Loss 12.55881
# Epoch 476, Loss 12.01053
# Epoch 477, Loss 11.31212
# Epoch 478, Loss 12.59728
# Epoch 479, Loss 11.93789
# Epoch 480, Loss 11.25312
# Epoch 481, Loss 11.74967
# Epoch 482, Loss 11.16846
# Epoch 483, Loss 11.74609
# Epoch 484, Loss 12.13266
# Epoch 485, Loss 12.10659
# Epoch 486, Loss 11.93270
# Epoch 487, Loss 11.11870
# Epoch 488, Loss 12.00665
# Epoch 489, Loss 12.08807
# Epoch 490, Loss 11.11368
# Epoch 491, Loss 11.19286
# Epoch 492, Loss 12.15937
# Epoch 493, Loss 10.52445
# Epoch 494, Loss 11.07120
# Epoch 495, Loss 11.61900
# Epoch 496, Loss 11.72597
# Epoch 497, Loss 11.92228
# Epoch 498, Loss 11.98680
# Epoch 499, Loss 12.92270
# Epoch 500, Loss 12.39195
# Epoch 501, Loss 12.34374
# Epoch 502, Loss 12.50863
# Epoch 503, Loss 11.57861
# Epoch 504, Loss 10.19661
# Epoch 505, Loss 12.48051
# Epoch 506, Loss 11.89407
# Epoch 507, Loss 12.33645
# Epoch 508, Loss 13.01844
# Epoch 509, Loss 12.03490
# Epoch 510, Loss 11.68207
# Epoch 511, Loss 11.84274
# Epoch 512, Loss 11.05808
# Epoch 513, Loss 12.41449
# Epoch 514, Loss 12.50156
# Epoch 515, Loss 13.20796
# Epoch 516, Loss 10.83926
# Epoch 517, Loss 12.21088
# Epoch 518, Loss 11.54871
# Epoch 519, Loss 12.35333
# Epoch 520, Loss 12.51973
# Epoch 521, Loss 12.65040
# Epoch 522, Loss 10.11016
# Epoch 523, Loss 11.48924
# Epoch 524, Loss 10.59237
# Epoch 525, Loss 12.28161
# Epoch 526, Loss 11.92183
# Epoch 527, Loss 11.32147
# Epoch 528, Loss 13.22440
# Epoch 529, Loss 11.87093
# Epoch 530, Loss 11.74265
# Epoch 531, Loss 12.73788
# Epoch 532, Loss 11.16212
# Epoch 533, Loss 13.00019
# Epoch 534, Loss 10.88461
# Epoch 535, Loss 12.79824
# Epoch 536, Loss 11.87826
# Epoch 537, Loss 12.39229
# Epoch 538, Loss 12.90564
# Epoch 539, Loss 11.50260
# Epoch 540, Loss 11.25205
# Epoch 541, Loss 11.72669
# Epoch 542, Loss 11.79211
# Epoch 543, Loss 11.36737
# Epoch 544, Loss 12.79734
# Epoch 545, Loss 12.37185
# Epoch 546, Loss 12.15304
# Epoch 547, Loss 11.48860
# Epoch 548, Loss 11.75256
# Epoch 549, Loss 11.90782
# Epoch 550, Loss 11.31868
# Epoch 551, Loss 11.23074
# Epoch 552, Loss 11.48190
# Epoch 553, Loss 11.35514
# Epoch 554, Loss 13.22101
# Epoch 555, Loss 12.55312
# Epoch 556, Loss 12.56204
# Epoch 557, Loss 12.06160
# Epoch 558, Loss 12.17006
# Epoch 559, Loss 12.22501
# Epoch 560, Loss 11.98231
# Epoch 561, Loss 13.28081
# Epoch 562, Loss 11.93174
# Epoch 563, Loss 12.83725
# Epoch 564, Loss 11.75143
# Epoch 565, Loss 11.54349
# Epoch 566, Loss 12.86405
# Epoch 567, Loss 11.71353
# Epoch 568, Loss 12.00034
# Epoch 569, Loss 13.67671
# Epoch 570, Loss 12.28063
# Epoch 571, Loss 11.72694
# Epoch 572, Loss 12.44553
# Epoch 573, Loss 11.41696
# Epoch 574, Loss 11.69658
# Epoch 575, Loss 11.07726
# Epoch 576, Loss 11.76008
# Epoch 577, Loss 11.27107
# Epoch 578, Loss 11.12028
# Epoch 579, Loss 10.95931
# Epoch 580, Loss 13.21984
# Epoch 581, Loss 10.41106
# Epoch 582, Loss 13.24111
# Epoch 583, Loss 11.65611
# Epoch 584, Loss 11.36625
# Epoch 585, Loss 11.73375
# Epoch 586, Loss 11.59849
# Epoch 587, Loss 11.61259
# Epoch 588, Loss 12.53989
# Epoch 589, Loss 11.35373
# Epoch 590, Loss 12.51128
# Epoch 591, Loss 12.39343
# Epoch 592, Loss 11.50122
# Epoch 593, Loss 11.46097
# Epoch 594, Loss 11.42519
# Epoch 595, Loss 12.36048
# Epoch 596, Loss 11.04239
# Epoch 597, Loss 13.15713
# Epoch 598, Loss 11.69414
# Epoch 599, Loss 10.43213
# Epoch 600, Loss 12.59632
# Epoch 601, Loss 12.58498
# Epoch 602, Loss 11.84791
# Epoch 603, Loss 12.23848
# Epoch 604, Loss 11.24321
# Epoch 605, Loss 11.87804
# Epoch 606, Loss 10.29465
# Epoch 607, Loss 13.02909
# Epoch 608, Loss 12.70483
# Epoch 609, Loss 10.89312
# Epoch 610, Loss 10.98774
# Epoch 611, Loss 13.05097
# Epoch 612, Loss 11.24406
# Epoch 613, Loss 12.29180
# Epoch 614, Loss 11.02102
# Epoch 615, Loss 11.63815
# Epoch 616, Loss 12.05737
# Epoch 617, Loss 9.96069
# Epoch 618, Loss 9.43129
# Epoch 619, Loss 11.57163
# Epoch 620, Loss 11.43257
# Epoch 621, Loss 10.28436
# Epoch 622, Loss 11.88398
# Epoch 623, Loss 12.64643
# Epoch 624, Loss 11.91432
# Epoch 625, Loss 10.87360
# Epoch 626, Loss 12.06482
# Epoch 627, Loss 11.01928
# Epoch 628, Loss 14.76273
# Epoch 629, Loss 11.49177
# Epoch 630, Loss 11.88305
# Epoch 631, Loss 12.51064
# Epoch 632, Loss 11.98379
# Epoch 633, Loss 10.59963
# Epoch 634, Loss 11.96647
# Epoch 635, Loss 12.17897
# Epoch 636, Loss 12.58722
# Epoch 637, Loss 11.21134
# Epoch 638, Loss 13.03616
# Epoch 639, Loss 10.25922
# Epoch 640, Loss 12.28619
# Epoch 641, Loss 12.63407
# Epoch 642, Loss 11.28762
# Epoch 643, Loss 11.78417
# Epoch 644, Loss 10.37319
# Epoch 645, Loss 12.04838
# Epoch 646, Loss 12.54561
# Epoch 647, Loss 12.77458
# Epoch 648, Loss 11.34328
# Epoch 649, Loss 12.00828
# Epoch 650, Loss 12.74756
# Epoch 651, Loss 12.50691
# Epoch 652, Loss 10.86872
# Epoch 653, Loss 12.36201
# Epoch 654, Loss 11.43270
# Epoch 655, Loss 11.17699
# Epoch 656, Loss 12.75436
# Epoch 657, Loss 11.00004
# Epoch 658, Loss 13.86510
# Epoch 659, Loss 12.55792
# Epoch 660, Loss 12.15103
# Epoch 661, Loss 11.44168
# Epoch 662, Loss 12.64328
# Epoch 663, Loss 13.30141
# Epoch 664, Loss 12.45549
# Epoch 665, Loss 12.13378
# Epoch 666, Loss 11.78365
# Epoch 667, Loss 12.09473
# Epoch 668, Loss 12.42946
# Epoch 669, Loss 11.84215
# Epoch 670, Loss 11.98719
# Epoch 671, Loss 11.96109
# Epoch 672, Loss 10.66061
# Epoch 673, Loss 11.69449
# Epoch 674, Loss 12.15641
# Epoch 675, Loss 12.41587
# Epoch 676, Loss 10.84947
# Epoch 677, Loss 13.43463
# Epoch 678, Loss 11.78468
# Epoch 679, Loss 11.71188
# Epoch 680, Loss 11.89983
# Epoch 681, Loss 13.00421
# Epoch 682, Loss 11.24152
# Epoch 683, Loss 12.82640
# Epoch 684, Loss 11.03699
# Epoch 685, Loss 12.41841
# Epoch 686, Loss 11.20291
# Epoch 687, Loss 11.30237
# Epoch 688, Loss 11.73207
# Epoch 689, Loss 13.85948
# Epoch 690, Loss 11.56605
# Epoch 691, Loss 11.37487
# Epoch 692, Loss 12.56571
# Epoch 693, Loss 12.66256
# Epoch 694, Loss 12.25796
# Epoch 695, Loss 11.60425
# Epoch 696, Loss 11.52798
# Epoch 697, Loss 13.12092
# Epoch 698, Loss 10.65961
# Epoch 699, Loss 11.26458
# Epoch 700, Loss 11.26245
# Epoch 701, Loss 11.59473
# Epoch 702, Loss 12.80114
# Epoch 703, Loss 12.64159
# Epoch 704, Loss 12.20671
# Epoch 705, Loss 13.12185
# Epoch 706, Loss 11.37729
# Epoch 707, Loss 11.67551
# Epoch 708, Loss 10.64835
# Epoch 709, Loss 13.23347
# Epoch 710, Loss 11.51628
# Epoch 711, Loss 11.63494
# Epoch 712, Loss 11.42593
# Epoch 713, Loss 11.84266
# Epoch 714, Loss 12.89225
# Epoch 715, Loss 10.71282
# Epoch 716, Loss 12.49561
# Epoch 717, Loss 12.42837
# Epoch 718, Loss 12.49899
# Epoch 719, Loss 13.25278
# Epoch 720, Loss 12.52935
# Epoch 721, Loss 11.83245
# Epoch 722, Loss 10.42659
# Epoch 723, Loss 14.03449
# Epoch 724, Loss 11.55051
# Epoch 725, Loss 11.65203
# Epoch 726, Loss 12.43391
# Epoch 727, Loss 11.47155
# Epoch 728, Loss 12.04509
# Epoch 729, Loss 11.89385
# Epoch 730, Loss 12.11800
# Epoch 731, Loss 12.05392
# Epoch 732, Loss 11.74547
# Epoch 733, Loss 12.75066
# Epoch 734, Loss 12.07036
# Epoch 735, Loss 11.39688
# Epoch 736, Loss 12.30291
# Epoch 737, Loss 12.68159
# Epoch 738, Loss 12.11031
# Epoch 739, Loss 12.55781
# Epoch 740, Loss 12.22028
# Epoch 741, Loss 12.92093
# Epoch 742, Loss 11.73528
# Epoch 743, Loss 13.54908
# Epoch 744, Loss 11.70649
# Epoch 745, Loss 11.09395
# Epoch 746, Loss 11.12619
# Epoch 747, Loss 12.54638
# Epoch 748, Loss 11.86562
# Epoch 749, Loss 11.65080
# Epoch 750, Loss 11.85739
# Epoch 751, Loss 11.75405
# Epoch 752, Loss 11.98128
# Epoch 753, Loss 10.84222
# Epoch 754, Loss 12.54741
# Epoch 755, Loss 11.52173
# Epoch 756, Loss 11.50251
# Epoch 757, Loss 11.98251
# Epoch 758, Loss 10.92534
# Epoch 759, Loss 11.65831
# Epoch 760, Loss 12.36253
# Epoch 761, Loss 11.69534
# Epoch 762, Loss 12.76382
# Epoch 763, Loss 11.82320
# Epoch 764, Loss 11.87942
# Epoch 765, Loss 11.18788
# Epoch 766, Loss 12.05752
# Epoch 767, Loss 13.92850
# Epoch 768, Loss 11.45618
# Epoch 769, Loss 10.97105
# Epoch 770, Loss 13.30357
# Epoch 771, Loss 11.30707
# Epoch 772, Loss 13.14261
# Epoch 773, Loss 12.03738
# Epoch 774, Loss 11.95593
# Epoch 775, Loss 12.52808
# Epoch 776, Loss 12.36846
# Epoch 777, Loss 13.24245
# Epoch 778, Loss 11.52813
# Epoch 779, Loss 11.91199
# Epoch 780, Loss 11.35703
# Epoch 781, Loss 11.41940
# Epoch 782, Loss 12.68134
# Epoch 783, Loss 11.74015
# Epoch 784, Loss 12.44728
# Epoch 785, Loss 12.54930
# Epoch 786, Loss 13.36677
# Epoch 787, Loss 11.67455
# Epoch 788, Loss 12.52376
# Epoch 789, Loss 12.72614
# Epoch 790, Loss 13.23693
# Epoch 791, Loss 11.84522
# Epoch 792, Loss 12.42024
# Epoch 793, Loss 12.86342
# Epoch 794, Loss 13.04048
# Epoch 795, Loss 11.83916
# Epoch 796, Loss 11.45570
# Epoch 797, Loss 11.92638
# Epoch 798, Loss 12.35043
# Epoch 799, Loss 12.57601
# Epoch 800, Loss 11.52124
# Epoch 801, Loss 12.35553
# Epoch 802, Loss 10.48629
# Epoch 803, Loss 12.70637
# Epoch 804, Loss 11.15375
# Epoch 805, Loss 11.68984
# Epoch 806, Loss 12.80235
# Epoch 807, Loss 11.58673
# Epoch 808, Loss 11.93696
# Epoch 809, Loss 11.83708
# Epoch 810, Loss 12.23389
# Epoch 811, Loss 10.65183
# Epoch 812, Loss 11.15283
# Epoch 813, Loss 12.33513
# Epoch 814, Loss 13.13032
# Epoch 815, Loss 10.98778
# Epoch 816, Loss 12.35609
# Epoch 817, Loss 11.51660
# Epoch 818, Loss 12.63134
# Epoch 819, Loss 12.14477
# Epoch 820, Loss 12.36157
# Epoch 821, Loss 10.39172
# Epoch 822, Loss 11.07679
# Epoch 823, Loss 11.67217
# Epoch 824, Loss 12.07499
# Epoch 825, Loss 11.68986
# Epoch 826, Loss 12.47122
# Epoch 827, Loss 11.33661
# Epoch 828, Loss 11.91869
# Epoch 829, Loss 11.49471
# Epoch 830, Loss 11.73350
# Epoch 831, Loss 12.65461
# Epoch 832, Loss 12.33054
# Epoch 833, Loss 11.94346
# Epoch 834, Loss 12.69122
# Epoch 835, Loss 12.76348
# Epoch 836, Loss 11.56053
# Epoch 837, Loss 11.09957
# Epoch 838, Loss 11.45259
# Epoch 839, Loss 11.96200
# Epoch 840, Loss 11.55396
# Epoch 841, Loss 12.95733
# Epoch 842, Loss 12.71141
# Epoch 843, Loss 11.96250
# Epoch 844, Loss 11.98790
# Epoch 845, Loss 12.99019
# Epoch 846, Loss 10.29127
# Epoch 847, Loss 12.16094
# Epoch 848, Loss 10.39793
# Epoch 849, Loss 12.21426
# Epoch 850, Loss 10.55967
# Epoch 851, Loss 10.98355
# Epoch 852, Loss 12.63929
# Epoch 853, Loss 11.53309
# Epoch 854, Loss 12.29324
# Epoch 855, Loss 12.20923
# Epoch 856, Loss 12.55703
# Epoch 857, Loss 11.78169
# Epoch 858, Loss 11.14907
# Epoch 859, Loss 11.19250
# Epoch 860, Loss 11.69564
# Epoch 861, Loss 12.42002
# Epoch 862, Loss 11.24413
# Epoch 863, Loss 11.97644
# Epoch 864, Loss 11.11939
# Epoch 865, Loss 11.31086
# Epoch 866, Loss 11.53495
# Epoch 867, Loss 11.04798
# Epoch 868, Loss 11.72819
# Epoch 869, Loss 12.88259
# Epoch 870, Loss 11.85312
# Epoch 871, Loss 12.76320
# Epoch 872, Loss 10.94755
# Epoch 873, Loss 12.73780
# Epoch 874, Loss 11.42600
# Epoch 875, Loss 13.13401
# Epoch 876, Loss 13.36740
# Epoch 877, Loss 12.84066
# Epoch 878, Loss 11.77939
# Epoch 879, Loss 12.54373
# Epoch 880, Loss 10.71152
# Epoch 881, Loss 12.24371
# Epoch 882, Loss 11.10509
# Epoch 883, Loss 13.84945
# Epoch 884, Loss 12.51741
# Epoch 885, Loss 13.90837
# Epoch 886, Loss 11.85154
# Epoch 887, Loss 11.87562
# Epoch 888, Loss 11.73493
# Epoch 889, Loss 12.37429
# Epoch 890, Loss 11.44246
# Epoch 891, Loss 10.25549
# Epoch 892, Loss 11.72463
# Epoch 893, Loss 11.55618
# Epoch 894, Loss 11.65912
# Epoch 895, Loss 13.93278
# Epoch 896, Loss 12.56544
# Epoch 897, Loss 12.14837
# Epoch 898, Loss 11.07185
# Epoch 899, Loss 12.96448
# Epoch 900, Loss 10.76745
# Epoch 901, Loss 11.37558
# Epoch 902, Loss 13.13260
# Epoch 903, Loss 11.75646
# Epoch 904, Loss 11.59457
# Epoch 905, Loss 11.26391
# Epoch 906, Loss 10.52889
# Epoch 907, Loss 13.14827
# Epoch 908, Loss 12.64872
# Epoch 909, Loss 11.38405
# Epoch 910, Loss 12.95106
# Epoch 911, Loss 11.68543
# Epoch 912, Loss 12.85507
# Epoch 913, Loss 12.05854
# Epoch 914, Loss 12.09645
# Epoch 915, Loss 11.80109
# Epoch 916, Loss 12.65079
# Epoch 917, Loss 12.74552
# Epoch 918, Loss 12.09390
# Epoch 919, Loss 11.63067
# Epoch 920, Loss 10.96171
# Epoch 921, Loss 12.47517
# Epoch 922, Loss 11.84043
# Epoch 923, Loss 12.35521
# Epoch 924, Loss 11.40499
# Epoch 925, Loss 12.13633
# Epoch 926, Loss 11.86697
# Epoch 927, Loss 12.25922
# Epoch 928, Loss 11.28485
# Epoch 929, Loss 12.02267
# Epoch 930, Loss 11.37443
# Epoch 931, Loss 11.48979
# Epoch 932, Loss 12.16507
# Epoch 933, Loss 10.75343
# Epoch 934, Loss 12.93868
# Epoch 935, Loss 13.18109
# Epoch 936, Loss 11.53889
# Epoch 937, Loss 14.35826
# Epoch 938, Loss 12.16380
# Epoch 939, Loss 11.77826
# Epoch 940, Loss 13.35394
# Epoch 941, Loss 11.40437
# Epoch 942, Loss 11.28676
# Epoch 943, Loss 12.35558
# Epoch 944, Loss 11.39043
# Epoch 945, Loss 11.69953
# Epoch 946, Loss 11.95109
# Epoch 947, Loss 12.96629
# Epoch 948, Loss 12.13427
# Epoch 949, Loss 12.49544
# Epoch 950, Loss 12.31833
# Epoch 951, Loss 12.32375
# Epoch 952, Loss 12.67398
# Epoch 953, Loss 12.37246
# Epoch 954, Loss 12.67530
# Epoch 955, Loss 11.56295
# Epoch 956, Loss 12.88946
# Epoch 957, Loss 11.20490
# Epoch 958, Loss 13.05667
# Epoch 959, Loss 10.34185
# Epoch 960, Loss 11.72308
# Epoch 961, Loss 10.71419
# Epoch 962, Loss 12.86720
# Epoch 963, Loss 11.49880
# Epoch 964, Loss 11.36207
# Epoch 965, Loss 12.04946
# Epoch 966, Loss 11.87319
# Epoch 967, Loss 11.86872
# Epoch 968, Loss 12.29192
# Epoch 969, Loss 11.93228
# Epoch 970, Loss 12.36470
# Epoch 971, Loss 11.15719
# Epoch 972, Loss 13.47956
# Epoch 973, Loss 11.21028
# Epoch 974, Loss 11.91338
# Epoch 975, Loss 12.42044
# Epoch 976, Loss 12.25296
# Epoch 977, Loss 12.95713
# Epoch 978, Loss 11.31708
# Epoch 979, Loss 12.20744
# Epoch 980, Loss 11.00671
# Epoch 981, Loss 12.84093
# Epoch 982, Loss 12.93481
# Epoch 983, Loss 10.95794
# Epoch 984, Loss 11.85858
# Epoch 985, Loss 11.51883
# Epoch 986, Loss 11.80146
# Epoch 987, Loss 12.66651
# Epoch 988, Loss 12.82564
# Epoch 989, Loss 12.88981
# Epoch 990, Loss 11.52362
# Epoch 991, Loss 12.18500
# Epoch 992, Loss 12.12074
# Epoch 993, Loss 11.27003
# Epoch 994, Loss 14.76436
# Epoch 995, Loss 14.10151
# Epoch 996, Loss 10.98309
# Epoch 997, Loss 12.43370
# Epoch 998, Loss 12.12063
# Epoch 999, Loss 11.22644
# Epoch 1000, Loss 11.94273

# %%
# plot data
plt.figure(figsize=(10, 3))
plt.subplot(1, 3, 1)
plt.plot(t_span, y_mean, linestyle='--', c='k', alpha=.7)
plt.scatter(t, y)
plt.title('Training data')
# plt.ylim([0, 1.5])
plt.xlabel("time")
plt.ylabel('y(t)')

plt.subplot(1, 3, 2)
plt.plot(t_span, y_mean, linestyle='--', c='k', alpha=.7)
for _ in range(15):
    
    # random sample
    z = np.random.randn(M)
    w = T(z, theta)
    
    # sim model 
    y_sim = model_tspan(x0, t_span, w)
    plt.plot(t_span, y_sim, c='C0', alpha=.5)
plt.title('Model fit')
plt.xlabel("time")

# plot params
plt.subplot(1, 3, 3)
xp, yp = np.linspace(r-.5, r+.5, 100), np.linspace(k-.5, k+.5, 100)
X, Y = np.meshgrid(xp, yp)
pos = np.dstack((X, Y))

# unpack params
m, s = theta
# Cholesky of multivariate Gaussian distribution 
tril_indices = jnp.tril_indices(len(m))
L = np.zeros([M, M])
L[tril_indices] = s
cov = L@L.T
rv = multivariate_normal(m, cov)
Z = rv.pdf(pos)
plt.contour(X, Y, Z, levels=5, cmap='viridis', zorder=0)
plt.xlabel("Growth rate")
plt.ylabel("Carrying capacity")
plt.title("Parameter estimate")
plt.scatter([r],[k],label='True', zorder=1)
plt.legend()

plt.tight_layout()
plt.show()
