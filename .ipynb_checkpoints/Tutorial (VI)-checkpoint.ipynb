# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal

import jax.numpy as jnp
from jax.experimental.ode import odeint
from jax import vmap, jit, jacfwd, jacrev
from jax.nn import softplus, relu

# %% [markdown]
# Let $x(t)$ represent a vector of $n_x$ time dependent variables. We'll use an ordinary differential equation (ODE) model to characterize the rate of change of the variables,
#
# $$
# \frac{d x(t)}{d t} = f(x(t), w)
# $$
# where $w$ is a vector of $n_w$ learnable parameters.
#
# Model estimates of $x(t)$ are computed by integrating the ODE,
#
# $$
# y(t, x_0, w) = x_0 + \int_0^t f(x(t), w) d t
# $$
#
# Model estimates of $x(t)$ are denoted as $y(t, x_0, w)$ and measuremed values are denoted as $y(t)$.

# %% [markdown]
# Ground truth ODE model

# %%
# growth rate
r = .75

# carrying capacity
k = 1.2
    
def dxdt(x, t):
    
    # rate of change
    dxdt = x * (r - x/k)
    
    return dxdt

# %%
# initial condition
x0 = .1

# time frame 
t_span = np.linspace(0, 10, 50)

# simulate data
y_mean = odeint(dxdt, x0, t_span)

# sparsely sampled 
t_sparse = np.linspace(0, 10, 5)
y_sparse = odeint(dxdt, x0, t_sparse)

# %%
# plot data
plt.figure(figsize=(8, 3))
plt.subplot(1, 2, 1)
plt.plot(t_span, y_mean, linestyle='--', c='k', alpha=.7)
plt.scatter(t_span, y_mean + .01 * np.random.randn(len(y_mean)))
plt.title('low data uncertainty')
plt.ylim([0, 1.5])
plt.xlabel("time")
plt.ylabel('y(t)')

plt.subplot(1, 2, 2)
plt.plot(t_span, y_mean, linestyle='--', c='k', alpha=.7)
plt.scatter(t_span, y_mean + .1 * np.random.randn(len(y_mean)))
plt.title('high data uncertainty')
plt.ylim([0, 1.5])
plt.xlabel("time")
plt.show()

# %% [markdown]
# The distribution of the data conditioned on the input is important to characterize correctly and is used to define the likelihood function.
#
# In this case, the data distribution is Gaussian with mean $y(x_0, t, w)$ and variance $\beta^2$.
#
# $$
# p(y(t) | x_0, t, w, \beta) = \mathcal{N}(y(t) | y(x_0, t, w), \beta^2)
# $$

# %% [markdown]
# Variational Inference
#
# Goal of variational inference is to minimize the Kullback-Leibler divergence between an approximate posterior distribution and the true parameter posterior distribution.
#
# The true parameter distribution is given by Bayes' theorem as proportional to the product of the likelihood and the prior on parameters.
#
# With a data set denoted as $D = \{y(t_1), ..., y(t_N)\}$, the likelihood captures data uncertainty,
#
# $$
# p(D | w, \beta) = \prod_{i=1}^N \mathcal{N}(y(t_i) | y(x_0, t_i, w), \beta^2)
# $$
#
# A zero-mean Gaussian prior distribution promotes simplicity in the model,
#
# $$
# p(w_j) = \mathcal{N}(w_j | 0, \alpha_j)
# $$
#
# The postrior distribution is
#
# $$
# p(w | D, \alpha, \beta) = \frac{p(D | w, \beta) p(w)}{p(D|\alpha, \beta)}
# $$
#
# $$
# p(w | D, \alpha, \beta) = \frac{\prod_{i=1}^N \mathcal{N}(y(t_i) | y(x_0, t_i, w), \beta^2) \prod_{j=1}^{n_w} \mathcal{N}(w_j | 0, \alpha_j)}{p(D|\alpha, \beta)}
# $$
#
# The goal of variational inference is to approximate this distribution using a parametric distribution, $q(w | \theta)$. Optimization of $\theta$ is performed by minimizing the Kullback-Leibler divergence with the true posterior,
#
# $$
# \theta^* = \text{arg} \; \underset{\theta}{\text{min}} \;
# \text{KL} \left[ q(w | \theta) || p(w | D, \alpha, \beta) \right]
# $$
#
# where
#
# $$
# \text{KL} \left[ q(w | \theta) || p(w | D, \alpha, \beta) \right] =
# -\int_w q(w | \theta) \mathrm{ln} \frac{p(w | D, \alpha, \beta)}{q(w | \theta)} d w
# $$
#
# $$
# = -\int_w q(w | \theta) \mathrm{ln} p(w | D, \alpha, \beta) d w + \int_w q(w | \theta) \mathrm{ln} q(w | \theta) d w
# $$
#
# To enable a flexible class of approximating distributions, we'll use the change of variables formula to transform samples from a distribution that's easy to sample from,
#
# $$
# w = T(z, \theta), \quad z_j \sim \mathcal{N}(z_j | 0, 1)
# $$
#
# The change of variables formula gives,
#
# $$
# q(w | \theta) = p(z) \cdot | \mathrm{det} \nabla_{z} T(z, \theta) |^{-1}
# $$
#
# and
#
# $$
# \mathrm{ln} q(w|\theta) = \mathrm{ln} p(z) - \mathrm{ln} | \mathrm{det}
# \nabla_{z} T(z, \theta)|
# $$
#
# We can use a Monte Carlo estimate of the $KL$ divergence, where each $z_i^k \sim \mathcal{N}(0, 1)$,
#
# $$
# \text{KL} \left[ q(w | \theta) || p(w | D, \alpha, \beta) \right] \approx
# \frac{1}{K} \sum_{k=1}^K -\mathrm{ln} p(T(z^k, \theta) | D, \alpha, \beta) - \mathrm{ln} | \mathrm{det}
# \nabla_{z} T(z^k, \theta)|
# $$
#
# $$
# =\frac{1}{K} \sum_{k=1}^K \left( \sum_{i=1}^N -\mathrm{ln} \mathcal{N}(y(t_i) | y(x_0, t_i, T(z^k, \theta)), \beta^2) - \sum_{j=1}^{n_w} \mathrm{ln}\mathcal{N}(T_j(z^k, \theta) | 0, \alpha_j) -\mathrm{ln} | \mathrm{det}
# \nabla_{z} T(z^k, \theta)| \right)
# $$
#
# Keeping only terms that depend on $\theta$, we'll define the objective function
# $$
# J(\theta) =\frac{1}{K} \sum_{k=1}^K \left( \sum_{i=1}^N \frac{(y(t_i) - y(x_0, t_i, T(z^k, \theta))^2}{2 \beta^2} + \sum_{j=1}^{n_w} \frac{T_j^2(z^k, \theta)}{2 \alpha_j^2} - \mathrm{ln} | \mathrm{det}
# \nabla_{z} T(z^k, \theta)| \right)
# $$

# %%
# function to transform latent variables
def T(z, theta): 
    
    # unpack variational parameters 
    m, s = theta
    
    # independent Gaussian distribution 
    # w = softplus(m) + softplus(s) * z 
    w = m + jnp.exp(s) * z 
    
    return w 

# general function to compute log of absolute determinant 
def log_abs_det_T(z, theta):
    
    # Jacobian w.r.t. z 
    jac = jacfwd(T)(z, theta)
    
    # return log abs det 
    return jnp.log(jnp.abs(jnp.linalg.det(jac)))

# negative log likelihood component of KL divergence 
def neg_log_likelihood(y, x0, t, w, beta):
    
    # transform theta  
    # w = T(z, theta) 
    
    # model predictions 
    y_hat = model(x0, t, w)
    
    # return squared error 
    return (y - y_hat) ** 2 / beta ** 2 / 2.

# negative log of prior 
def neg_log_prior(w, alpha):
    
    # transform theta
    # w = T(z, theta)
    
    # return sum of squares
    return jnp.sum(w ** 2 / alpha ** 2) / 2. 

# overall per sample cost function 
@jit
def J(theta, z, y, x0, t, alpha, beta, M, N):
    
    # random sample
    w = T(z, theta)
    
    # negative log likelihood
    nll = neg_log_likelihood(y, x0, t, w, beta)
    
    # negative log prior
    nlp = neg_log_prior(w, alpha) / N 
    
    # posterior entropy
    lad = log_abs_det_T(z, theta) / N 
    
    return nll + nlp - lad 

# gradient of cost w.r.t. theta  
J_grad = jit(jacrev(J))

# %%
def adam(loss, grad, data, theta, params, n_sample=1, n_epochs=100, lr=1e-3, beta1=.9, beta2=.999, epsilon=1e-8):
    
    # unpack data set
    y, x0, t = data
    N = len(y)
    order = np.arange(N)
    
    # additional hyperparameters
    alpha, beta, M = params
    
    # init params 
    c = 0
    m = np.zeros_like(theta)
    v = np.zeros_like(theta)
    
    # loop over epochs
    for epoch in range(n_epochs):
    
        # sgd over each sample
        np.random.shuffle(order)
        epoch_loss = 0.
        for idx in order:
            
            # estimate gradient 
            gradient = 0.
            for _ in range(n_sample):
                
                # random sample
                z = np.random.randn(M)
                
                # evaluate gradient
                gradient += np.nan_to_num(grad(theta, 
                                               z, 
                                               y[idx], 
                                               x0[idx], 
                                               t[idx], 
                                               alpha, beta, M, N)) / n_sample
                
                # evaluate loss
                epoch_loss += np.nan_to_num(loss(theta, 
                                                 z, 
                                                 y[idx], 
                                                 x0[idx], 
                                                 t[idx], 
                                                 alpha, beta, M, N)) / n_sample

            # moment estimation
            c += 1   
            m = beta1 * m + (1 - beta1) * gradient
            v = beta2 * v + (1 - beta2) * (gradient ** 2)

            # adjust moments based on number of iterations
            m_hat = m / (1 - beta1 ** c)
            v_hat = v / (1 - beta2 ** c)

            # take step
            theta -= lr * m_hat / (np.sqrt(v_hat) + epsilon)
                
        print(f"Epoch {epoch+1:.0f}, Loss {epoch_loss:.5f}")
        
    # return params
    return theta

# %% [markdown]
# Define model to fit

# %%
# rate of change of model
def dmdt(x, t, w):
    
    # unpack model parameters
    r, k = w
    
    # rate of change
    # dxdt = x * (softplus(r) - x/softplus(k))
    dxdt = x * (r - x/k)
    # dxdt = x * (relu(r) - relu(k)*x)
    
    return dxdt 

# model integrates ode up to time t 
def model(x0, t, w):
    
    # integrate dmdt from x0 to xt 
    return odeint(dmdt, x0, jnp.linspace(0, t), w)[-1]

# model integrates ode up to time t 
def model_tspan(x0, tspan, w):
    
    # integrate dmdt from x0 to xt 
    return odeint(dmdt, x0, tspan, w)

# %%
# params 
alpha = 1.
beta = .1
M = 2 

# data set
x0 = .1
t = np.linspace(0., 10., 10)
y = odeint(dxdt, x0, t) + beta * np.append(0., np.random.randn(len(t)-1))
D = (y[1:], [x0]*len(y[1:]), t[1:])

# init params
mu = jnp.ones(M)
s = -jnp.ones(M)
theta = [mu, s]

# %%
theta = adam(J, J_grad, D, theta, (alpha, beta, M), lr=1e-4, n_sample=5, n_epochs=3000)
# Out:
# Epoch 1, Loss 193.05750
# Epoch 2, Loss 68.18947
# Epoch 3, Loss 154.94106
# Epoch 4, Loss 89.97193
# Epoch 5, Loss 146.10315
# Epoch 6, Loss 110.08711
# Epoch 7, Loss 124.09399
# Epoch 8, Loss 121.18941
# Epoch 9, Loss 182.58982
# Epoch 10, Loss 86.59817
# Epoch 11, Loss 128.67783
# Epoch 12, Loss 104.58756
# Epoch 13, Loss 166.04516
# Epoch 14, Loss 169.94561
# Epoch 15, Loss 140.21291
# Epoch 16, Loss 109.49342
# Epoch 17, Loss 114.79228
# Epoch 18, Loss 96.75299
# Epoch 19, Loss 87.06549
# Epoch 20, Loss 88.88332
# Epoch 21, Loss 118.74695
# Epoch 22, Loss 146.28015
# Epoch 23, Loss 106.99362
# Epoch 24, Loss 64.81125
# Epoch 25, Loss 111.92992
# Epoch 26, Loss 110.61910
# Epoch 27, Loss 153.73555
# Epoch 28, Loss 95.12862
# Epoch 29, Loss 92.38699
# Epoch 30, Loss 101.84167
# Epoch 31, Loss 67.74709
# Epoch 32, Loss 87.01152
# Epoch 33, Loss 118.58562
# Epoch 34, Loss 115.70887
# Epoch 35, Loss 82.38267
# Epoch 36, Loss 121.08999
# Epoch 37, Loss 88.77726
# Epoch 38, Loss 94.15157
# Epoch 39, Loss 68.38061
# Epoch 40, Loss 72.07579
# Epoch 41, Loss 118.67666
# Epoch 42, Loss 104.24946
# Epoch 43, Loss 107.07379
# Epoch 44, Loss 171.81677
# Epoch 45, Loss 90.35270
# Epoch 46, Loss 111.87844
# Epoch 47, Loss 111.95999
# Epoch 48, Loss 103.49429
# Epoch 49, Loss 115.51029
# Epoch 50, Loss 100.49142
# Epoch 51, Loss 76.14958
# Epoch 52, Loss 104.13716
# Epoch 53, Loss 99.14209
# Epoch 54, Loss 100.07713
# Epoch 55, Loss 116.76334
# Epoch 56, Loss 101.49101
# Epoch 57, Loss 55.09645
# Epoch 58, Loss 99.21431
# Epoch 59, Loss 104.28164
# Epoch 60, Loss 145.21381
# Epoch 61, Loss 116.61651
# Epoch 62, Loss 103.42300
# Epoch 63, Loss 98.95785
# Epoch 64, Loss 109.31568
# Epoch 65, Loss 124.91867
# Epoch 66, Loss 86.91990
# Epoch 67, Loss 88.65524
# Epoch 68, Loss 121.86282
# Epoch 69, Loss 142.26235
# Epoch 70, Loss 127.90576
# Epoch 71, Loss 106.08363
# Epoch 72, Loss 99.96115
# Epoch 73, Loss 95.86589
# Epoch 74, Loss 83.02713
# Epoch 75, Loss 136.08201
# Epoch 76, Loss 95.89646
# Epoch 77, Loss 73.97838
# Epoch 78, Loss 109.70218
# Epoch 79, Loss 88.57816
# Epoch 80, Loss 99.01277
# Epoch 81, Loss 125.52440
# Epoch 82, Loss 100.75989
# Epoch 83, Loss 111.53442
# Epoch 84, Loss 100.16871
# Epoch 85, Loss 120.82902
# Epoch 86, Loss 113.39485
# Epoch 87, Loss 103.02419
# Epoch 88, Loss 106.31443
# Epoch 89, Loss 100.77845
# Epoch 90, Loss 82.28847
# Epoch 91, Loss 127.79800
# Epoch 92, Loss 120.62299
# Epoch 93, Loss 98.35502
# Epoch 94, Loss 149.80782
# Epoch 95, Loss 123.58538
# Epoch 96, Loss 90.48613
# Epoch 97, Loss 90.43293
# Epoch 98, Loss 97.34269
# Epoch 99, Loss 82.39265
# Epoch 100, Loss 114.73364
# Epoch 101, Loss 126.31746
# Epoch 102, Loss 100.64876
# Epoch 103, Loss 97.66894
# Epoch 104, Loss 96.37784
# Epoch 105, Loss 103.18545
# Epoch 106, Loss 88.83870
# Epoch 107, Loss 145.71883
# Epoch 108, Loss 49.63255
# Epoch 109, Loss 94.35104
# Epoch 110, Loss 84.91881
# Epoch 111, Loss 103.18670
# Epoch 112, Loss 96.38999
# Epoch 113, Loss 125.86710
# Epoch 114, Loss 97.36069
# Epoch 115, Loss 91.25223
# Epoch 116, Loss 102.58678
# Epoch 117, Loss 91.92339
# Epoch 118, Loss 115.81106
# Epoch 119, Loss 93.83983
# Epoch 120, Loss 82.60704
# Epoch 121, Loss 78.54332
# Epoch 122, Loss 108.20887
# Epoch 123, Loss 102.89928
# Epoch 124, Loss 82.46327
# Epoch 125, Loss 94.35187
# Epoch 126, Loss 121.06877
# Epoch 127, Loss 103.39896
# Epoch 128, Loss 76.78621
# Epoch 129, Loss 96.27140
# Epoch 130, Loss 87.25528
# Epoch 131, Loss 147.68264
# Epoch 132, Loss 68.58105
# Epoch 133, Loss 76.11437
# Epoch 134, Loss 89.65480
# Epoch 135, Loss 76.87016
# Epoch 136, Loss 86.66388
# Epoch 137, Loss 86.44328
# Epoch 138, Loss 119.76829
# Epoch 139, Loss 106.58383
# Epoch 140, Loss 104.11716
# Epoch 141, Loss 107.44445
# Epoch 142, Loss 74.55848
# Epoch 143, Loss 88.91273
# Epoch 144, Loss 68.73404
# Epoch 145, Loss 72.04814
# Epoch 146, Loss 65.01210
# Epoch 147, Loss 100.95249
# Epoch 148, Loss 101.48906
# Epoch 149, Loss 93.51372
# Epoch 150, Loss 125.97885
# Epoch 151, Loss 119.03020
# Epoch 152, Loss 93.57022
# Epoch 153, Loss 82.76368
# Epoch 154, Loss 94.16605
# Epoch 155, Loss 96.89914
# Epoch 156, Loss 70.50509
# Epoch 157, Loss 85.50152
# Epoch 158, Loss 110.24737
# Epoch 159, Loss 77.58088
# Epoch 160, Loss 53.58984
# Epoch 161, Loss 63.17233
# Epoch 162, Loss 61.54612
# Epoch 163, Loss 110.51893
# Epoch 164, Loss 78.69182
# Epoch 165, Loss 108.45538
# Epoch 166, Loss 117.27352
# Epoch 167, Loss 84.82860
# Epoch 168, Loss 86.65957
# Epoch 169, Loss 78.35628
# Epoch 170, Loss 86.34929
# Epoch 171, Loss 77.41087
# Epoch 172, Loss 175.56278
# Epoch 173, Loss 113.93734
# Epoch 174, Loss 163.87077
# Epoch 175, Loss 172.16209
# Epoch 176, Loss 82.67329
# Epoch 177, Loss 91.30640
# Epoch 178, Loss 49.66003
# Epoch 179, Loss 126.33245
# Epoch 180, Loss 91.96355
# Epoch 181, Loss 47.68844
# Epoch 182, Loss 86.46197
# Epoch 183, Loss 109.13589
# Epoch 184, Loss 145.24362
# Epoch 185, Loss 136.67939
# Epoch 186, Loss 126.58959
# Epoch 187, Loss 104.82405
# Epoch 188, Loss 59.25558
# Epoch 189, Loss 113.59919
# Epoch 190, Loss 87.85804
# Epoch 191, Loss 86.60254
# Epoch 192, Loss 93.35217
# Epoch 193, Loss 83.30900
# Epoch 194, Loss 97.30083
# Epoch 195, Loss 144.57473
# Epoch 196, Loss 76.31843
# Epoch 197, Loss 74.25641
# Epoch 198, Loss 96.69595
# Epoch 199, Loss 155.94296
# Epoch 200, Loss 73.32099
# Epoch 201, Loss 75.87349
# Epoch 202, Loss 73.48726
# Epoch 203, Loss 66.15871
# Epoch 204, Loss 71.37660
# Epoch 205, Loss 110.62158
# Epoch 206, Loss 79.97121
# Epoch 207, Loss 69.00587
# Epoch 208, Loss 66.29229
# Epoch 209, Loss 79.13063
# Epoch 210, Loss 95.71972
# Epoch 211, Loss 72.44096
# Epoch 212, Loss 97.48678
# Epoch 213, Loss 62.27622
# Epoch 214, Loss 100.09680
# Epoch 215, Loss 61.56597
# Epoch 216, Loss 83.74195
# Epoch 217, Loss 71.32459
# Epoch 218, Loss 100.14407
# Epoch 219, Loss 78.02305
# Epoch 220, Loss 130.38000
# Epoch 221, Loss 85.28434
# Epoch 222, Loss 83.09640
# Epoch 223, Loss 68.19350
# Epoch 224, Loss 84.16945
# Epoch 225, Loss 73.39439
# Epoch 226, Loss 79.84510
# Epoch 227, Loss 84.70114
# Epoch 228, Loss 83.89433
# Epoch 229, Loss 111.41242
# Epoch 230, Loss 68.12026
# Epoch 231, Loss 68.90264
# Epoch 232, Loss 77.05206
# Epoch 233, Loss 104.62770
# Epoch 234, Loss 97.98785
# Epoch 235, Loss 80.53537
# Epoch 236, Loss 96.65813
# Epoch 237, Loss 121.10639
# Epoch 238, Loss 76.03116
# Epoch 239, Loss 83.12992
# Epoch 240, Loss 82.73021
# Epoch 241, Loss 101.14762
# Epoch 242, Loss 75.35132
# Epoch 243, Loss 64.73217
# Epoch 244, Loss 92.53042
# Epoch 245, Loss 86.83545
# Epoch 246, Loss 117.48078
# Epoch 247, Loss 89.11069
# Epoch 248, Loss 91.52687
# Epoch 249, Loss 68.43723
# Epoch 250, Loss 98.30247
# Epoch 251, Loss 71.17112
# Epoch 252, Loss 61.90498
# Epoch 253, Loss 102.68976
# Epoch 254, Loss 62.89352
# Epoch 255, Loss 87.99167
# Epoch 256, Loss 116.04861
# Epoch 257, Loss 103.14979
# Epoch 258, Loss 82.79335
# Epoch 259, Loss 80.44999
# Epoch 260, Loss 76.82651
# Epoch 261, Loss 100.86075
# Epoch 262, Loss 70.86492
# Epoch 263, Loss 65.64036
# Epoch 264, Loss 53.63747
# Epoch 265, Loss 60.90437
# Epoch 266, Loss 106.32701
# Epoch 267, Loss 86.82207
# Epoch 268, Loss 67.75176
# Epoch 269, Loss 120.12753
# Epoch 270, Loss 98.29474
# Epoch 271, Loss 99.50300
# Epoch 272, Loss 83.90160
# Epoch 273, Loss 63.45948
# Epoch 274, Loss 105.83370
# Epoch 275, Loss 85.17954
# Epoch 276, Loss 88.46194
# Epoch 277, Loss 71.11494
# Epoch 278, Loss 92.91864
# Epoch 279, Loss 91.57059
# Epoch 280, Loss 78.79577
# Epoch 281, Loss 67.33490
# Epoch 282, Loss 78.48849
# Epoch 283, Loss 95.58353
# Epoch 284, Loss 70.61577
# Epoch 285, Loss 74.30672
# Epoch 286, Loss 92.34584
# Epoch 287, Loss 76.41621
# Epoch 288, Loss 86.34755
# Epoch 289, Loss 84.93476
# Epoch 290, Loss 90.32773
# Epoch 291, Loss 79.49955
# Epoch 292, Loss 89.81643
# Epoch 293, Loss 79.84402
# Epoch 294, Loss 78.33033
# Epoch 295, Loss 95.85398
# Epoch 296, Loss 78.04810
# Epoch 297, Loss 112.00184
# Epoch 298, Loss 72.51881
# Epoch 299, Loss 103.74285
# Epoch 300, Loss 107.15808
# Epoch 301, Loss 72.17270
# Epoch 302, Loss 74.82218
# Epoch 303, Loss 73.43379
# Epoch 304, Loss 64.33845
# Epoch 305, Loss 74.76788
# Epoch 306, Loss 75.33791
# Epoch 307, Loss 123.86292
# Epoch 308, Loss 77.34497
# Epoch 309, Loss 80.54282
# Epoch 310, Loss 91.69124
# Epoch 311, Loss 99.34471
# Epoch 312, Loss 94.81998
# Epoch 313, Loss 97.29221
# Epoch 314, Loss 94.74719
# Epoch 315, Loss 64.38107
# Epoch 316, Loss 77.38299
# Epoch 317, Loss 80.64988
# Epoch 318, Loss 97.89611
# Epoch 319, Loss 75.75204
# Epoch 320, Loss 112.63435
# Epoch 321, Loss 95.37329
# Epoch 322, Loss 75.83408
# Epoch 323, Loss 69.47014
# Epoch 324, Loss 89.00539
# Epoch 325, Loss 99.85103
# Epoch 326, Loss 83.30360
# Epoch 327, Loss 68.04707
# Epoch 328, Loss 69.16823
# Epoch 329, Loss 55.27308
# Epoch 330, Loss 85.25130
# Epoch 331, Loss 63.90725
# Epoch 332, Loss 83.61241
# Epoch 333, Loss 88.06740
# Epoch 334, Loss 92.65926
# Epoch 335, Loss 62.97797
# Epoch 336, Loss 96.88001
# Epoch 337, Loss 93.54395
# Epoch 338, Loss 72.34496
# Epoch 339, Loss 68.92233
# Epoch 340, Loss 74.97865
# Epoch 341, Loss 71.47743
# Epoch 342, Loss 76.97422
# Epoch 343, Loss 75.02801
# Epoch 344, Loss 47.45595
# Epoch 345, Loss 90.09780
# Epoch 346, Loss 86.31179
# Epoch 347, Loss 77.92457
# Epoch 348, Loss 57.46539
# Epoch 349, Loss 86.83231
# Epoch 350, Loss 66.53885
# Epoch 351, Loss 99.01788
# Epoch 352, Loss 39.38016
# Epoch 353, Loss 56.43513
# Epoch 354, Loss 60.24904
# Epoch 355, Loss 72.45601
# Epoch 356, Loss 69.75811
# Epoch 357, Loss 100.03686
# Epoch 358, Loss 60.41085
# Epoch 359, Loss 53.72041
# Epoch 360, Loss 64.20371
# Epoch 361, Loss 69.90961
# Epoch 362, Loss 63.66095
# Epoch 363, Loss 84.89055
# Epoch 364, Loss 66.97920
# Epoch 365, Loss 67.74410
# Epoch 366, Loss 59.60006
# Epoch 367, Loss 95.94400
# Epoch 368, Loss 93.08063
# Epoch 369, Loss 57.89016
# Epoch 370, Loss 88.03201
# Epoch 371, Loss 95.49337
# Epoch 372, Loss 67.08963
# Epoch 373, Loss 77.47367
# Epoch 374, Loss 91.62903
# Epoch 375, Loss 119.88479
# Epoch 376, Loss 55.79744
# Epoch 377, Loss 63.89641
# Epoch 378, Loss 90.60927
# Epoch 379, Loss 57.96204
# Epoch 380, Loss 92.52449
# Epoch 381, Loss 75.53010
# Epoch 382, Loss 63.14903
# Epoch 383, Loss 92.86005
# Epoch 384, Loss 84.60299
# Epoch 385, Loss 113.59751
# Epoch 386, Loss 71.79498
# Epoch 387, Loss 89.03946
# Epoch 388, Loss 83.97039
# Epoch 389, Loss 70.84596
# Epoch 390, Loss 76.82849
# Epoch 391, Loss 69.38882
# Epoch 392, Loss 107.08378
# Epoch 393, Loss 62.43109
# Epoch 394, Loss 59.40549
# Epoch 395, Loss 76.74735
# Epoch 396, Loss 84.31806
# Epoch 397, Loss 100.70093
# Epoch 398, Loss 103.59533
# Epoch 399, Loss 96.90580
# Epoch 400, Loss 67.04423
# Epoch 401, Loss 79.50990
# Epoch 402, Loss 62.76026
# Epoch 403, Loss 75.72728
# Epoch 404, Loss 80.14010
# Epoch 405, Loss 70.10595
# Epoch 406, Loss 88.20770
# Epoch 407, Loss 91.25467
# Epoch 408, Loss 89.54943
# Epoch 409, Loss 68.49606
# Epoch 410, Loss 63.22026
# Epoch 411, Loss 80.58081
# Epoch 412, Loss 81.80210
# Epoch 413, Loss 70.63663
# Epoch 414, Loss 81.67127
# Epoch 415, Loss 83.81262
# Epoch 416, Loss 88.52324
# Epoch 417, Loss 74.55047
# Epoch 418, Loss 67.10538
# Epoch 419, Loss 76.24943
# Epoch 420, Loss 59.01873
# Epoch 421, Loss 65.92925
# Epoch 422, Loss 107.01423
# Epoch 423, Loss 68.65205
# Epoch 424, Loss 67.05389
# Epoch 425, Loss 84.24972
# Epoch 426, Loss 39.25980
# Epoch 427, Loss 73.86111
# Epoch 428, Loss 63.45284
# Epoch 429, Loss 76.29228
# Epoch 430, Loss 53.13560
# Epoch 431, Loss 63.75226
# Epoch 432, Loss 56.18738
# Epoch 433, Loss 58.10414
# Epoch 434, Loss 54.28059
# Epoch 435, Loss 90.90077
# Epoch 436, Loss 62.25326
# Epoch 437, Loss 90.78171
# Epoch 438, Loss 81.73263
# Epoch 439, Loss 80.33919
# Epoch 440, Loss 87.85971
# Epoch 441, Loss 64.24438
# Epoch 442, Loss 80.23559
# Epoch 443, Loss 94.44948
# Epoch 444, Loss 56.69710
# Epoch 445, Loss 66.81593
# Epoch 446, Loss 72.77535
# Epoch 447, Loss 82.77214
# Epoch 448, Loss 87.68455
# Epoch 449, Loss 88.42030
# Epoch 450, Loss 43.79371
# Epoch 451, Loss 78.70859
# Epoch 452, Loss 66.85290
# Epoch 453, Loss 78.69918
# Epoch 454, Loss 86.85253
# Epoch 455, Loss 61.84772
# Epoch 456, Loss 65.74577
# Epoch 457, Loss 74.02138
# Epoch 458, Loss 80.55216
# Epoch 459, Loss 84.52913
# Epoch 460, Loss 73.60117
# Epoch 461, Loss 75.59842
# Epoch 462, Loss 68.50846
# Epoch 463, Loss 50.17616
# Epoch 464, Loss 64.03187
# Epoch 465, Loss 74.26217
# Epoch 466, Loss 72.51927
# Epoch 467, Loss 56.75020
# Epoch 468, Loss 76.25630
# Epoch 469, Loss 80.79537
# Epoch 470, Loss 93.17988
# Epoch 471, Loss 122.34905
# Epoch 472, Loss 65.21206
# Epoch 473, Loss 61.58399
# Epoch 474, Loss 67.43273
# Epoch 475, Loss 66.60683
# Epoch 476, Loss 69.09004
# Epoch 477, Loss 76.71162
# Epoch 478, Loss 69.86001
# Epoch 479, Loss 80.17377
# Epoch 480, Loss 42.64679
# Epoch 481, Loss 89.87157
# Epoch 482, Loss 85.57640
# Epoch 483, Loss 75.24076
# Epoch 484, Loss 89.46764
# Epoch 485, Loss 85.22757
# Epoch 486, Loss 49.33305
# Epoch 487, Loss 60.78243
# Epoch 488, Loss 72.91354
# Epoch 489, Loss 59.59954
# Epoch 490, Loss 72.77573
# Epoch 491, Loss 68.26673
# Epoch 492, Loss 64.19998
# Epoch 493, Loss 67.04338
# Epoch 494, Loss 73.14576
# Epoch 495, Loss 66.46427
# Epoch 496, Loss 49.52965
# Epoch 497, Loss 70.16921
# Epoch 498, Loss 67.13309
# Epoch 499, Loss 68.94000
# Epoch 500, Loss 65.77561
# Epoch 501, Loss 71.51154
# Epoch 502, Loss 54.62270
# Epoch 503, Loss 54.12540
# Epoch 504, Loss 64.19301
# Epoch 505, Loss 68.01705
# Epoch 506, Loss 62.49566
# Epoch 507, Loss 84.96060
# Epoch 508, Loss 54.84762
# Epoch 509, Loss 77.13060
# Epoch 510, Loss 90.74392
# Epoch 511, Loss 53.31943
# Epoch 512, Loss 72.79857
# Epoch 513, Loss 57.06213
# Epoch 514, Loss 64.11678
# Epoch 515, Loss 84.82786
# Epoch 516, Loss 45.29017
# Epoch 517, Loss 54.92052
# Epoch 518, Loss 79.08385
# Epoch 519, Loss 62.65246
# Epoch 520, Loss 55.31686
# Epoch 521, Loss 73.27359
# Epoch 522, Loss 67.61552
# Epoch 523, Loss 68.70098
# Epoch 524, Loss 66.00194
# Epoch 525, Loss 75.18969
# Epoch 526, Loss 100.57438
# Epoch 527, Loss 61.96000
# Epoch 528, Loss 72.11771
# Epoch 529, Loss 78.33245
# Epoch 530, Loss 77.07497
# Epoch 531, Loss 86.73840
# Epoch 532, Loss 76.07441
# Epoch 533, Loss 55.10095
# Epoch 534, Loss 55.41913
# Epoch 535, Loss 63.88559
# Epoch 536, Loss 51.95119
# Epoch 537, Loss 61.92542
# Epoch 538, Loss 75.95564
# Epoch 539, Loss 61.20014
# Epoch 540, Loss 56.91787
# Epoch 541, Loss 56.92325
# Epoch 542, Loss 65.29269
# Epoch 543, Loss 91.26884
# Epoch 544, Loss 65.32272
# Epoch 545, Loss 62.60679
# Epoch 546, Loss 64.96742
# Epoch 547, Loss 59.95828
# Epoch 548, Loss 83.67213
# Epoch 549, Loss 76.02227
# Epoch 550, Loss 57.15686
# Epoch 551, Loss 77.54613
# Epoch 552, Loss 71.24551
# Epoch 553, Loss 53.55109
# Epoch 554, Loss 69.42903
# Epoch 555, Loss 71.13872
# Epoch 556, Loss 53.42371
# Epoch 557, Loss 75.99325
# Epoch 558, Loss 55.15517
# Epoch 559, Loss 64.19275
# Epoch 560, Loss 54.26468
# Epoch 561, Loss 61.14561
# Epoch 562, Loss 58.49477
# Epoch 563, Loss 74.74767
# Epoch 564, Loss 48.55895
# Epoch 565, Loss 50.00461
# Epoch 566, Loss 75.41788
# Epoch 567, Loss 80.98061
# Epoch 568, Loss 59.55893
# Epoch 569, Loss 61.16517
# Epoch 570, Loss 75.35108
# Epoch 571, Loss 49.82498
# Epoch 572, Loss 73.25459
# Epoch 573, Loss 65.99986
# Epoch 574, Loss 70.97040
# Epoch 575, Loss 68.26668
# Epoch 576, Loss 51.26675
# Epoch 577, Loss 52.48554
# Epoch 578, Loss 54.01722
# Epoch 579, Loss 68.24859
# Epoch 580, Loss 61.15959
# Epoch 581, Loss 60.43659
# Epoch 582, Loss 47.64049
# Epoch 583, Loss 55.42768
# Epoch 584, Loss 65.89699
# Epoch 585, Loss 54.12640
# Epoch 586, Loss 53.13321
# Epoch 587, Loss 59.41381
# Epoch 588, Loss 77.62291
# Epoch 589, Loss 68.24774
# Epoch 590, Loss 64.06282
# Epoch 591, Loss 88.89559
# Epoch 592, Loss 52.08613
# Epoch 593, Loss 45.59218
# Epoch 594, Loss 71.09052
# Epoch 595, Loss 63.40678
# Epoch 596, Loss 82.10260
# Epoch 597, Loss 64.70596
# Epoch 598, Loss 49.46185
# Epoch 599, Loss 44.23584
# Epoch 600, Loss 78.73586
# Epoch 601, Loss 45.61825
# Epoch 602, Loss 93.21952
# Epoch 603, Loss 79.98676
# Epoch 604, Loss 77.01056
# Epoch 605, Loss 88.84282
# Epoch 606, Loss 55.45316
# Epoch 607, Loss 47.87369
# Epoch 608, Loss 59.44352
# Epoch 609, Loss 61.32284
# Epoch 610, Loss 52.38352
# Epoch 611, Loss 57.94919
# Epoch 612, Loss 50.89624
# Epoch 613, Loss 58.07302
# Epoch 614, Loss 80.68515
# Epoch 615, Loss 74.04611
# Epoch 616, Loss 74.35558
# Epoch 617, Loss 69.23015
# Epoch 618, Loss 75.24942
# Epoch 619, Loss 48.03296
# Epoch 620, Loss 67.91085
# Epoch 621, Loss 62.60715
# Epoch 622, Loss 56.25269
# Epoch 623, Loss 49.23983
# Epoch 624, Loss 56.85933
# Epoch 625, Loss 62.75648
# Epoch 626, Loss 51.96677
# Epoch 627, Loss 66.20684
# Epoch 628, Loss 68.59358
# Epoch 629, Loss 55.61468
# Epoch 630, Loss 54.23497
# Epoch 631, Loss 72.31197
# Epoch 632, Loss 65.56760
# Epoch 633, Loss 65.86011
# Epoch 634, Loss 76.49542
# Epoch 635, Loss 61.12757
# Epoch 636, Loss 54.78997
# Epoch 637, Loss 88.44109
# Epoch 638, Loss 50.45019
# Epoch 639, Loss 45.58193
# Epoch 640, Loss 74.57631
# Epoch 641, Loss 69.18591
# Epoch 642, Loss 54.45347
# Epoch 643, Loss 38.11987
# Epoch 644, Loss 112.26721
# Epoch 645, Loss 44.75685
# Epoch 646, Loss 98.50712
# Epoch 647, Loss 63.51269
# Epoch 648, Loss 51.86350
# Epoch 649, Loss 55.18541
# Epoch 650, Loss 69.39624
# Epoch 651, Loss 58.17577
# Epoch 652, Loss 54.52635
# Epoch 653, Loss 39.77628
# Epoch 654, Loss 55.43035
# Epoch 655, Loss 54.23413
# Epoch 656, Loss 58.30965
# Epoch 657, Loss 55.89117
# Epoch 658, Loss 64.57517
# Epoch 659, Loss 59.49175
# Epoch 660, Loss 60.97691
# Epoch 661, Loss 70.40197
# Epoch 662, Loss 74.38113
# Epoch 663, Loss 38.98930
# Epoch 664, Loss 51.83772
# Epoch 665, Loss 57.04703
# Epoch 666, Loss 51.11493
# Epoch 667, Loss 49.80994
# Epoch 668, Loss 59.11730
# Epoch 669, Loss 61.78826
# Epoch 670, Loss 55.52412
# Epoch 671, Loss 59.88025
# Epoch 672, Loss 84.76002
# Epoch 673, Loss 71.29324
# Epoch 674, Loss 73.52858
# Epoch 675, Loss 36.21679
# Epoch 676, Loss 45.62162
# Epoch 677, Loss 50.71138
# Epoch 678, Loss 52.12384
# Epoch 679, Loss 49.92083
# Epoch 680, Loss 50.67405
# Epoch 681, Loss 41.98321
# Epoch 682, Loss 57.59939
# Epoch 683, Loss 73.56564
# Epoch 684, Loss 47.75227
# Epoch 685, Loss 47.51374
# Epoch 686, Loss 64.49829
# Epoch 687, Loss 46.87162
# Epoch 688, Loss 56.33762
# Epoch 689, Loss 52.44725
# Epoch 690, Loss 85.52212
# Epoch 691, Loss 77.00305
# Epoch 692, Loss 46.53826
# Epoch 693, Loss 43.20030
# Epoch 694, Loss 69.18607
# Epoch 695, Loss 65.06687
# Epoch 696, Loss 58.80508
# Epoch 697, Loss 39.81596
# Epoch 698, Loss 64.47588
# Epoch 699, Loss 64.38390
# Epoch 700, Loss 37.96845
# Epoch 701, Loss 48.85027
# Epoch 702, Loss 62.04632
# Epoch 703, Loss 46.60034
# Epoch 704, Loss 55.94236
# Epoch 705, Loss 64.20922
# Epoch 706, Loss 61.87541
# Epoch 707, Loss 44.47503
# Epoch 708, Loss 63.29673
# Epoch 709, Loss 54.30819
# Epoch 710, Loss 66.42292
# Epoch 711, Loss 40.64911
# Epoch 712, Loss 57.49605
# Epoch 713, Loss 38.85925
# Epoch 714, Loss 57.12380
# Epoch 715, Loss 53.05975
# Epoch 716, Loss 63.65894
# Epoch 717, Loss 62.51618
# Epoch 718, Loss 45.08660
# Epoch 719, Loss 68.03025
# Epoch 720, Loss 64.13203
# Epoch 721, Loss 58.12949
# Epoch 722, Loss 46.89065
# Epoch 723, Loss 48.62405
# Epoch 724, Loss 50.14545
# Epoch 725, Loss 54.97433
# Epoch 726, Loss 42.17075
# Epoch 727, Loss 32.84846
# Epoch 728, Loss 72.18144
# Epoch 729, Loss 54.93629
# Epoch 730, Loss 39.95023
# Epoch 731, Loss 46.95818
# Epoch 732, Loss 42.56316
# Epoch 733, Loss 55.29189
# Epoch 734, Loss 46.47598
# Epoch 735, Loss 65.76374
# Epoch 736, Loss 55.49415
# Epoch 737, Loss 51.44969
# Epoch 738, Loss 44.34117
# Epoch 739, Loss 48.99831
# Epoch 740, Loss 56.90242
# Epoch 741, Loss 65.66916
# Epoch 742, Loss 56.21475
# Epoch 743, Loss 58.72582
# Epoch 744, Loss 65.72199
# Epoch 745, Loss 43.52925
# Epoch 746, Loss 34.23258
# Epoch 747, Loss 45.56026
# Epoch 748, Loss 42.80736
# Epoch 749, Loss 63.32996
# Epoch 750, Loss 59.25682
# Epoch 751, Loss 64.84227
# Epoch 752, Loss 62.62813
# Epoch 753, Loss 76.89833
# Epoch 754, Loss 65.91620
# Epoch 755, Loss 51.54750
# Epoch 756, Loss 25.53025
# Epoch 757, Loss 65.57770
# Epoch 758, Loss 50.29767
# Epoch 759, Loss 59.23138
# Epoch 760, Loss 44.43767
# Epoch 761, Loss 52.27556
# Epoch 762, Loss 51.30877
# Epoch 763, Loss 54.35508
# Epoch 764, Loss 89.64996
# Epoch 765, Loss 51.82264
# Epoch 766, Loss 54.85873
# Epoch 767, Loss 59.51817
# Epoch 768, Loss 49.00340
# Epoch 769, Loss 51.14823
# Epoch 770, Loss 57.56330
# Epoch 771, Loss 56.41754
# Epoch 772, Loss 49.43775
# Epoch 773, Loss 69.99331
# Epoch 774, Loss 48.74193
# Epoch 775, Loss 46.31741
# Epoch 776, Loss 71.75520
# Epoch 777, Loss 45.40071
# Epoch 778, Loss 49.13922
# Epoch 779, Loss 47.59521
# Epoch 780, Loss 46.81443
# Epoch 781, Loss 44.60055
# Epoch 782, Loss 52.26220
# Epoch 783, Loss 54.35324
# Epoch 784, Loss 59.08542
# Epoch 785, Loss 54.88251
# Epoch 786, Loss 44.91096
# Epoch 787, Loss 37.13966
# Epoch 788, Loss 52.57143
# Epoch 789, Loss 36.82316
# Epoch 790, Loss 45.19941
# Epoch 791, Loss 63.43022
# Epoch 792, Loss 68.34719
# Epoch 793, Loss 54.56876
# Epoch 794, Loss 57.41526
# Epoch 795, Loss 49.44242
# Epoch 796, Loss 69.50635
# Epoch 797, Loss 61.83373
# Epoch 798, Loss 56.84481
# Epoch 799, Loss 55.27467
# Epoch 800, Loss 60.02872
# Epoch 801, Loss 56.98537
# Epoch 802, Loss 58.45341
# Epoch 803, Loss 64.82822
# Epoch 804, Loss 36.31045
# Epoch 805, Loss 61.05127
# Epoch 806, Loss 57.05775
# Epoch 807, Loss 35.29167
# Epoch 808, Loss 62.89764
# Epoch 809, Loss 50.51290
# Epoch 810, Loss 50.54267
# Epoch 811, Loss 53.06635
# Epoch 812, Loss 74.97489
# Epoch 813, Loss 54.06872
# Epoch 814, Loss 47.65373
# Epoch 815, Loss 45.02932
# Epoch 816, Loss 78.96607
# Epoch 817, Loss 43.53171
# Epoch 818, Loss 48.41694
# Epoch 819, Loss 59.31891
# Epoch 820, Loss 38.96554
# Epoch 821, Loss 59.61312
# Epoch 822, Loss 56.03864
# Epoch 823, Loss 35.72807
# Epoch 824, Loss 56.13341
# Epoch 825, Loss 47.57929
# Epoch 826, Loss 50.61726
# Epoch 827, Loss 37.19003
# Epoch 828, Loss 43.14820
# Epoch 829, Loss 56.80280
# Epoch 830, Loss 37.07777
# Epoch 831, Loss 37.30520
# Epoch 832, Loss 48.87226
# Epoch 833, Loss 57.17272
# Epoch 834, Loss 48.96058
# Epoch 835, Loss 61.69249
# Epoch 836, Loss 52.78293
# Epoch 837, Loss 47.61424
# Epoch 838, Loss 45.72685
# Epoch 839, Loss 38.29234
# Epoch 840, Loss 65.66992
# Epoch 841, Loss 50.75601
# Epoch 842, Loss 30.93939
# Epoch 843, Loss 49.29837
# Epoch 844, Loss 58.11439
# Epoch 845, Loss 41.95342
# Epoch 846, Loss 47.78538
# Epoch 847, Loss 47.29810
# Epoch 848, Loss 48.26838
# Epoch 849, Loss 51.86198
# Epoch 850, Loss 46.77821
# Epoch 851, Loss 73.45728
# Epoch 852, Loss 38.80583
# Epoch 853, Loss 35.86784
# Epoch 854, Loss 39.55518
# Epoch 855, Loss 55.00208
# Epoch 856, Loss 36.70428
# Epoch 857, Loss 42.60915
# Epoch 858, Loss 58.02630
# Epoch 859, Loss 64.03688
# Epoch 860, Loss 65.94956
# Epoch 861, Loss 70.82269
# Epoch 862, Loss 47.95196
# Epoch 863, Loss 50.32456
# Epoch 864, Loss 51.19916
# Epoch 865, Loss 53.76990
# Epoch 866, Loss 41.57749
# Epoch 867, Loss 72.03177
# Epoch 868, Loss 61.55186
# Epoch 869, Loss 51.07531
# Epoch 870, Loss 57.15207
# Epoch 871, Loss 47.96879
# Epoch 872, Loss 56.23942
# Epoch 873, Loss 62.13823
# Epoch 874, Loss 68.10343
# Epoch 875, Loss 45.71448
# Epoch 876, Loss 47.79823
# Epoch 877, Loss 53.54516
# Epoch 878, Loss 52.34379
# Epoch 879, Loss 53.57707
# Epoch 880, Loss 37.80508
# Epoch 881, Loss 41.21171
# Epoch 882, Loss 35.20140
# Epoch 883, Loss 49.95597
# Epoch 884, Loss 56.50530
# Epoch 885, Loss 46.02184
# Epoch 886, Loss 56.26495
# Epoch 887, Loss 58.90219
# Epoch 888, Loss 50.52026
# Epoch 889, Loss 52.26964
# Epoch 890, Loss 44.32616
# Epoch 891, Loss 45.57890
# Epoch 892, Loss 50.76639
# Epoch 893, Loss 39.83132
# Epoch 894, Loss 39.54712
# Epoch 895, Loss 40.70824
# Epoch 896, Loss 42.21272
# Epoch 897, Loss 49.56266
# Epoch 898, Loss 49.87026
# Epoch 899, Loss 57.52340
# Epoch 900, Loss 35.10406
# Epoch 901, Loss 64.62259
# Epoch 902, Loss 48.05610
# Epoch 903, Loss 43.12478
# Epoch 904, Loss 45.81947
# Epoch 905, Loss 44.74372
# Epoch 906, Loss 49.62550
# Epoch 907, Loss 35.24038
# Epoch 908, Loss 38.66956
# Epoch 909, Loss 45.86909
# Epoch 910, Loss 28.07666
# Epoch 911, Loss 32.73960
# Epoch 912, Loss 67.83693
# Epoch 913, Loss 63.43619
# Epoch 914, Loss 55.28788
# Epoch 915, Loss 41.43369
# Epoch 916, Loss 42.87875
# Epoch 917, Loss 55.08259
# Epoch 918, Loss 46.49326
# Epoch 919, Loss 35.78392
# Epoch 920, Loss 39.03405
# Epoch 921, Loss 53.15881
# Epoch 922, Loss 48.52641
# Epoch 923, Loss 40.63810
# Epoch 924, Loss 44.26367
# Epoch 925, Loss 44.20688
# Epoch 926, Loss 40.38325
# Epoch 927, Loss 68.85166
# Epoch 928, Loss 42.69039
# Epoch 929, Loss 41.04968
# Epoch 930, Loss 42.86720
# Epoch 931, Loss 50.44007
# Epoch 932, Loss 34.99857
# Epoch 933, Loss 39.47809
# Epoch 934, Loss 35.50120
# Epoch 935, Loss 56.43827
# Epoch 936, Loss 46.58923
# Epoch 937, Loss 62.94736
# Epoch 938, Loss 63.88591
# Epoch 939, Loss 34.07793
# Epoch 940, Loss 43.36796
# Epoch 941, Loss 57.88097
# Epoch 942, Loss 42.61913
# Epoch 943, Loss 39.07816
# Epoch 944, Loss 46.35760
# Epoch 945, Loss 56.41970
# Epoch 946, Loss 52.54722
# Epoch 947, Loss 48.40872
# Epoch 948, Loss 41.81103
# Epoch 949, Loss 44.07631
# Epoch 950, Loss 31.82610
# Epoch 951, Loss 59.04981
# Epoch 952, Loss 46.93125
# Epoch 953, Loss 56.65865
# Epoch 954, Loss 52.04825
# Epoch 955, Loss 43.00661
# Epoch 956, Loss 48.72821
# Epoch 957, Loss 49.73612
# Epoch 958, Loss 43.36016
# Epoch 959, Loss 37.08946
# Epoch 960, Loss 53.43269
# Epoch 961, Loss 50.30215
# Epoch 962, Loss 62.94751
# Epoch 963, Loss 52.59828
# Epoch 964, Loss 51.04341
# Epoch 965, Loss 43.20892
# Epoch 966, Loss 53.27418
# Epoch 967, Loss 57.05208
# Epoch 968, Loss 67.36215
# Epoch 969, Loss 63.67068
# Epoch 970, Loss 52.54996
# Epoch 971, Loss 47.06519
# Epoch 972, Loss 41.55285
# Epoch 973, Loss 55.65056
# Epoch 974, Loss 46.52953
# Epoch 975, Loss 40.86822
# Epoch 976, Loss 64.72472
# Epoch 977, Loss 40.39564
# Epoch 978, Loss 37.26646
# Epoch 979, Loss 46.60995
# Epoch 980, Loss 35.79351
# Epoch 981, Loss 50.09551
# Epoch 982, Loss 47.05284
# Epoch 983, Loss 41.64987
# Epoch 984, Loss 48.14268
# Epoch 985, Loss 25.21217
# Epoch 986, Loss 43.89623
# Epoch 987, Loss 40.96156
# Epoch 988, Loss 62.04151
# Epoch 989, Loss 49.50887
# Epoch 990, Loss 44.05466
# Epoch 991, Loss 47.42033
# Epoch 992, Loss 60.52311
# Epoch 993, Loss 33.67625
# Epoch 994, Loss 53.12531
# Epoch 995, Loss 54.10546
# Epoch 996, Loss 52.48897
# Epoch 997, Loss 50.80576
# Epoch 998, Loss 36.84229
# Epoch 999, Loss 41.16848
# Epoch 1000, Loss 33.31879
# Epoch 1001, Loss 40.95500
# Epoch 1002, Loss 46.06308
# Epoch 1003, Loss 52.65434
# Epoch 1004, Loss 43.44582
# Epoch 1005, Loss 43.97599
# Epoch 1006, Loss 36.46512
# Epoch 1007, Loss 31.84290
# Epoch 1008, Loss 44.88108
# Epoch 1009, Loss 41.23149
# Epoch 1010, Loss 38.78710
# Epoch 1011, Loss 54.87762
# Epoch 1012, Loss 35.90921
# Epoch 1013, Loss 44.60974
# Epoch 1014, Loss 48.25214
# Epoch 1015, Loss 63.52821
# Epoch 1016, Loss 46.08424
# Epoch 1017, Loss 36.01364
# Epoch 1018, Loss 37.96412
# Epoch 1019, Loss 36.44306
# Epoch 1020, Loss 44.26637
# Epoch 1021, Loss 41.65336
# Epoch 1022, Loss 48.63476
# Epoch 1023, Loss 46.13621
# Epoch 1024, Loss 48.10714
# Epoch 1025, Loss 44.34582
# Epoch 1026, Loss 38.45218
# Epoch 1027, Loss 44.60050
# Epoch 1028, Loss 42.46776
# Epoch 1029, Loss 39.83365
# Epoch 1030, Loss 55.99647
# Epoch 1031, Loss 40.85457
# Epoch 1032, Loss 40.71716
# Epoch 1033, Loss 37.66986
# Epoch 1034, Loss 38.71816
# Epoch 1035, Loss 38.01754
# Epoch 1036, Loss 38.97583
# Epoch 1037, Loss 42.00020
# Epoch 1038, Loss 38.07852
# Epoch 1039, Loss 29.33223
# Epoch 1040, Loss 49.11228
# Epoch 1041, Loss 48.88330
# Epoch 1042, Loss 51.48723
# Epoch 1043, Loss 55.80664
# Epoch 1044, Loss 27.95657
# Epoch 1045, Loss 43.39742
# Epoch 1046, Loss 51.76517
# Epoch 1047, Loss 32.88861
# Epoch 1048, Loss 43.12827
# Epoch 1049, Loss 39.86915
# Epoch 1050, Loss 39.01643
# Epoch 1051, Loss 30.03678
# Epoch 1052, Loss 59.45103
# Epoch 1053, Loss 47.53163
# Epoch 1054, Loss 48.43588
# Epoch 1055, Loss 30.65316
# Epoch 1056, Loss 36.89639
# Epoch 1057, Loss 45.69735
# Epoch 1058, Loss 40.67576
# Epoch 1059, Loss 58.44395
# Epoch 1060, Loss 46.89567
# Epoch 1061, Loss 50.62110
# Epoch 1062, Loss 38.59810
# Epoch 1063, Loss 37.47611
# Epoch 1064, Loss 52.00232
# Epoch 1065, Loss 43.00763
# Epoch 1066, Loss 55.67026
# Epoch 1067, Loss 43.47157
# Epoch 1068, Loss 30.46404
# Epoch 1069, Loss 33.77418
# Epoch 1070, Loss 46.03569
# Epoch 1071, Loss 44.29779
# Epoch 1072, Loss 55.51656
# Epoch 1073, Loss 43.90059
# Epoch 1074, Loss 62.82572
# Epoch 1075, Loss 39.85759
# Epoch 1076, Loss 55.84785
# Epoch 1077, Loss 47.25054
# Epoch 1078, Loss 24.62246
# Epoch 1079, Loss 49.89364
# Epoch 1080, Loss 52.20832
# Epoch 1081, Loss 38.52130
# Epoch 1082, Loss 38.40984
# Epoch 1083, Loss 50.50816
# Epoch 1084, Loss 40.35816
# Epoch 1085, Loss 33.32191
# Epoch 1086, Loss 53.86384
# Epoch 1087, Loss 42.58776
# Epoch 1088, Loss 37.80851
# Epoch 1089, Loss 52.80486
# Epoch 1090, Loss 34.28952
# Epoch 1091, Loss 50.72667
# Epoch 1092, Loss 39.99724
# Epoch 1093, Loss 52.04910
# Epoch 1094, Loss 21.53495
# Epoch 1095, Loss 44.84862
# Epoch 1096, Loss 54.09450
# Epoch 1097, Loss 46.33525
# Epoch 1098, Loss 39.61644
# Epoch 1099, Loss 31.18121
# Epoch 1100, Loss 34.83784
# Epoch 1101, Loss 54.17521
# Epoch 1102, Loss 46.34128
# Epoch 1103, Loss 35.83753
# Epoch 1104, Loss 35.72107
# Epoch 1105, Loss 47.16224
# Epoch 1106, Loss 48.46675
# Epoch 1107, Loss 53.68300
# Epoch 1108, Loss 42.98993
# Epoch 1109, Loss 36.11366
# Epoch 1110, Loss 48.82334
# Epoch 1111, Loss 40.27374
# Epoch 1112, Loss 42.68798
# Epoch 1113, Loss 36.77889
# Epoch 1114, Loss 41.47041
# Epoch 1115, Loss 31.34693
# Epoch 1116, Loss 42.25668
# Epoch 1117, Loss 32.27784
# Epoch 1118, Loss 44.87539
# Epoch 1119, Loss 49.26362
# Epoch 1120, Loss 32.03169
# Epoch 1121, Loss 40.66293
# Epoch 1122, Loss 35.64110
# Epoch 1123, Loss 39.05237
# Epoch 1124, Loss 37.92433
# Epoch 1125, Loss 35.00825
# Epoch 1126, Loss 36.48953
# Epoch 1127, Loss 44.56341
# Epoch 1128, Loss 56.14121
# Epoch 1129, Loss 41.74509
# Epoch 1130, Loss 41.42800
# Epoch 1131, Loss 44.17641
# Epoch 1132, Loss 37.61659
# Epoch 1133, Loss 39.32452
# Epoch 1134, Loss 55.94855
# Epoch 1135, Loss 42.56973
# Epoch 1136, Loss 38.03523
# Epoch 1137, Loss 28.67031
# Epoch 1138, Loss 55.20287
# Epoch 1139, Loss 53.17282
# Epoch 1140, Loss 45.66772
# Epoch 1141, Loss 37.10643
# Epoch 1142, Loss 38.54901
# Epoch 1143, Loss 47.19339
# Epoch 1144, Loss 42.74087
# Epoch 1145, Loss 21.81536
# Epoch 1146, Loss 40.36761
# Epoch 1147, Loss 38.03951
# Epoch 1148, Loss 61.96628
# Epoch 1149, Loss 33.07225
# Epoch 1150, Loss 32.12696
# Epoch 1151, Loss 44.38041
# Epoch 1152, Loss 40.07562
# Epoch 1153, Loss 21.65054
# Epoch 1154, Loss 38.24639
# Epoch 1155, Loss 44.59469
# Epoch 1156, Loss 39.59406
# Epoch 1157, Loss 43.59499
# Epoch 1158, Loss 41.41288
# Epoch 1159, Loss 35.12199
# Epoch 1160, Loss 46.41856
# Epoch 1161, Loss 44.07227
# Epoch 1162, Loss 35.28370
# Epoch 1163, Loss 29.85830
# Epoch 1164, Loss 37.28794
# Epoch 1165, Loss 46.27075
# Epoch 1166, Loss 44.28779
# Epoch 1167, Loss 40.52123
# Epoch 1168, Loss 27.61563
# Epoch 1169, Loss 45.72358
# Epoch 1170, Loss 40.09862
# Epoch 1171, Loss 31.95607
# Epoch 1172, Loss 43.64080
# Epoch 1173, Loss 28.33645
# Epoch 1174, Loss 38.34347
# Epoch 1175, Loss 30.64237
# Epoch 1176, Loss 39.27781
# Epoch 1177, Loss 30.57198
# Epoch 1178, Loss 48.45032
# Epoch 1179, Loss 26.95939
# Epoch 1180, Loss 31.02660
# Epoch 1181, Loss 44.05151
# Epoch 1182, Loss 43.57332
# Epoch 1183, Loss 38.99872
# Epoch 1184, Loss 41.55075
# Epoch 1185, Loss 29.73384
# Epoch 1186, Loss 36.03189
# Epoch 1187, Loss 27.06532
# Epoch 1188, Loss 27.75410
# Epoch 1189, Loss 40.61411
# Epoch 1190, Loss 28.07682
# Epoch 1191, Loss 28.26162
# Epoch 1192, Loss 42.60426
# Epoch 1193, Loss 40.71417
# Epoch 1194, Loss 36.01461
# Epoch 1195, Loss 37.20029
# Epoch 1196, Loss 40.33911
# Epoch 1197, Loss 41.89710
# Epoch 1198, Loss 33.94239
# Epoch 1199, Loss 36.89518
# Epoch 1200, Loss 44.41679
# Epoch 1201, Loss 49.49960
# Epoch 1202, Loss 33.20855
# Epoch 1203, Loss 36.01905
# Epoch 1204, Loss 40.56220
# Epoch 1205, Loss 46.79523
# Epoch 1206, Loss 32.45381
# Epoch 1207, Loss 44.12476
# Epoch 1208, Loss 29.74089
# Epoch 1209, Loss 31.63265
# Epoch 1210, Loss 34.69610
# Epoch 1211, Loss 34.58912
# Epoch 1212, Loss 37.39517
# Epoch 1213, Loss 32.26233
# Epoch 1214, Loss 42.20869
# Epoch 1215, Loss 51.21034
# Epoch 1216, Loss 26.54235
# Epoch 1217, Loss 24.41476
# Epoch 1218, Loss 38.28843
# Epoch 1219, Loss 39.53453
# Epoch 1220, Loss 44.66398
# Epoch 1221, Loss 31.72504
# Epoch 1222, Loss 49.03532
# Epoch 1223, Loss 36.88432
# Epoch 1224, Loss 22.45347
# Epoch 1225, Loss 34.57462
# Epoch 1226, Loss 28.84117
# Epoch 1227, Loss 39.02696
# Epoch 1228, Loss 34.01423
# Epoch 1229, Loss 34.34236
# Epoch 1230, Loss 23.98453
# Epoch 1231, Loss 28.61571
# Epoch 1232, Loss 27.62445
# Epoch 1233, Loss 48.04723
# Epoch 1234, Loss 32.82945
# Epoch 1235, Loss 32.88938
# Epoch 1236, Loss 25.80777
# Epoch 1237, Loss 49.77881
# Epoch 1238, Loss 28.98011
# Epoch 1239, Loss 33.61321
# Epoch 1240, Loss 39.98614
# Epoch 1241, Loss 32.28616
# Epoch 1242, Loss 42.12762
# Epoch 1243, Loss 44.60841
# Epoch 1244, Loss 31.91191
# Epoch 1245, Loss 32.07250
# Epoch 1246, Loss 55.38225
# Epoch 1247, Loss 40.60913
# Epoch 1248, Loss 30.44810
# Epoch 1249, Loss 34.77788
# Epoch 1250, Loss 35.81745
# Epoch 1251, Loss 46.26375
# Epoch 1252, Loss 25.87420
# Epoch 1253, Loss 37.26348
# Epoch 1254, Loss 36.02124
# Epoch 1255, Loss 34.87856
# Epoch 1256, Loss 33.53992
# Epoch 1257, Loss 39.69493
# Epoch 1258, Loss 36.92115
# Epoch 1259, Loss 40.29234
# Epoch 1260, Loss 41.52812
# Epoch 1261, Loss 34.56651
# Epoch 1262, Loss 35.09839
# Epoch 1263, Loss 42.79101
# Epoch 1264, Loss 27.55344
# Epoch 1265, Loss 34.18703
# Epoch 1266, Loss 39.55381
# Epoch 1267, Loss 31.48990
# Epoch 1268, Loss 19.25236
# Epoch 1269, Loss 39.29231
# Epoch 1270, Loss 38.07427
# Epoch 1271, Loss 32.64947
# Epoch 1272, Loss 39.17594
# Epoch 1273, Loss 35.52520
# Epoch 1274, Loss 39.31905
# Epoch 1275, Loss 32.16329
# Epoch 1276, Loss 32.98372
# Epoch 1277, Loss 38.79691
# Epoch 1278, Loss 47.77080
# Epoch 1279, Loss 22.64775
# Epoch 1280, Loss 50.69261
# Epoch 1281, Loss 39.36164
# Epoch 1282, Loss 52.89918
# Epoch 1283, Loss 29.13266
# Epoch 1284, Loss 46.64970
# Epoch 1285, Loss 37.18952
# Epoch 1286, Loss 39.13461
# Epoch 1287, Loss 43.35762
# Epoch 1288, Loss 21.64015
# Epoch 1289, Loss 32.88831
# Epoch 1290, Loss 47.45026
# Epoch 1291, Loss 30.64866
# Epoch 1292, Loss 30.08928
# Epoch 1293, Loss 33.99987
# Epoch 1294, Loss 32.56318
# Epoch 1295, Loss 27.78383
# Epoch 1296, Loss 44.36360
# Epoch 1297, Loss 25.03194
# Epoch 1298, Loss 40.19017
# Epoch 1299, Loss 36.01044
# Epoch 1300, Loss 22.59083
# Epoch 1301, Loss 33.52427
# Epoch 1302, Loss 35.49308
# Epoch 1303, Loss 33.41011
# Epoch 1304, Loss 39.69279
# Epoch 1305, Loss 25.54495
# Epoch 1306, Loss 29.30501
# Epoch 1307, Loss 40.96853
# Epoch 1308, Loss 38.12832
# Epoch 1309, Loss 36.62979
# Epoch 1310, Loss 35.02822
# Epoch 1311, Loss 24.65479
# Epoch 1312, Loss 22.79728
# Epoch 1313, Loss 35.68450
# Epoch 1314, Loss 30.91256
# Epoch 1315, Loss 30.93805
# Epoch 1316, Loss 28.98894
# Epoch 1317, Loss 53.46453
# Epoch 1318, Loss 37.24577
# Epoch 1319, Loss 39.13869
# Epoch 1320, Loss 31.74760
# Epoch 1321, Loss 27.51705
# Epoch 1322, Loss 39.97208
# Epoch 1323, Loss 38.04454
# Epoch 1324, Loss 29.56266
# Epoch 1325, Loss 27.01907
# Epoch 1326, Loss 41.68102
# Epoch 1327, Loss 25.11178
# Epoch 1328, Loss 35.48262
# Epoch 1329, Loss 35.92892
# Epoch 1330, Loss 30.66568
# Epoch 1331, Loss 31.00221
# Epoch 1332, Loss 38.52827
# Epoch 1333, Loss 33.13884
# Epoch 1334, Loss 34.94467
# Epoch 1335, Loss 35.23381
# Epoch 1336, Loss 25.17059
# Epoch 1337, Loss 31.54836
# Epoch 1338, Loss 44.58529
# Epoch 1339, Loss 26.92500
# Epoch 1340, Loss 26.71676
# Epoch 1341, Loss 33.06957
# Epoch 1342, Loss 28.53141
# Epoch 1343, Loss 34.62468
# Epoch 1344, Loss 25.79208
# Epoch 1345, Loss 48.27667
# Epoch 1346, Loss 32.07503
# Epoch 1347, Loss 39.89140
# Epoch 1348, Loss 35.80526
# Epoch 1349, Loss 33.12962
# Epoch 1350, Loss 31.46783
# Epoch 1351, Loss 35.50544
# Epoch 1352, Loss 43.56315
# Epoch 1353, Loss 21.10018
# Epoch 1354, Loss 26.30708
# Epoch 1355, Loss 31.63942
# Epoch 1356, Loss 30.00321
# Epoch 1357, Loss 40.74213
# Epoch 1358, Loss 31.13482
# Epoch 1359, Loss 31.47777
# Epoch 1360, Loss 41.97413
# Epoch 1361, Loss 36.29047
# Epoch 1362, Loss 31.27646
# Epoch 1363, Loss 39.00841
# Epoch 1364, Loss 34.53263
# Epoch 1365, Loss 23.22359
# Epoch 1366, Loss 38.59974
# Epoch 1367, Loss 37.34877
# Epoch 1368, Loss 33.39618
# Epoch 1369, Loss 30.29549
# Epoch 1370, Loss 27.26203
# Epoch 1371, Loss 28.62918
# Epoch 1372, Loss 30.70652
# Epoch 1373, Loss 33.20862
# Epoch 1374, Loss 26.64190
# Epoch 1375, Loss 26.21920
# Epoch 1376, Loss 32.38855
# Epoch 1377, Loss 28.73560
# Epoch 1378, Loss 47.21485
# Epoch 1379, Loss 35.95204
# Epoch 1380, Loss 32.36556
# Epoch 1381, Loss 33.45785
# Epoch 1382, Loss 43.13421
# Epoch 1383, Loss 29.88480
# Epoch 1384, Loss 28.39487
# Epoch 1385, Loss 48.79559
# Epoch 1386, Loss 33.51215
# Epoch 1387, Loss 37.63521
# Epoch 1388, Loss 33.20900
# Epoch 1389, Loss 31.84135
# Epoch 1390, Loss 36.24311
# Epoch 1391, Loss 35.75573
# Epoch 1392, Loss 41.75840
# Epoch 1393, Loss 30.69464
# Epoch 1394, Loss 35.30342
# Epoch 1395, Loss 26.81347
# Epoch 1396, Loss 29.64851
# Epoch 1397, Loss 30.28346
# Epoch 1398, Loss 35.52497
# Epoch 1399, Loss 29.09436
# Epoch 1400, Loss 36.33621
# Epoch 1401, Loss 28.93519
# Epoch 1402, Loss 37.94827
# Epoch 1403, Loss 34.43299
# Epoch 1404, Loss 36.48251
# Epoch 1405, Loss 34.80653
# Epoch 1406, Loss 39.74880
# Epoch 1407, Loss 35.62446
# Epoch 1408, Loss 36.82986
# Epoch 1409, Loss 26.08975
# Epoch 1410, Loss 28.81671
# Epoch 1411, Loss 31.07648
# Epoch 1412, Loss 31.40458
# Epoch 1413, Loss 34.51734
# Epoch 1414, Loss 34.20688
# Epoch 1415, Loss 27.39505
# Epoch 1416, Loss 35.45625
# Epoch 1417, Loss 31.90164
# Epoch 1418, Loss 43.19901
# Epoch 1419, Loss 33.54874
# Epoch 1420, Loss 30.10332
# Epoch 1421, Loss 36.48221
# Epoch 1422, Loss 33.49729
# Epoch 1423, Loss 26.16440
# Epoch 1424, Loss 30.47222
# Epoch 1425, Loss 37.16419
# Epoch 1426, Loss 34.42700
# Epoch 1427, Loss 29.51928
# Epoch 1428, Loss 22.51570
# Epoch 1429, Loss 18.90214
# Epoch 1430, Loss 26.49591
# Epoch 1431, Loss 36.41592
# Epoch 1432, Loss 21.87809
# Epoch 1433, Loss 24.13614
# Epoch 1434, Loss 34.61046
# Epoch 1435, Loss 32.47951
# Epoch 1436, Loss 34.31772
# Epoch 1437, Loss 26.14830
# Epoch 1438, Loss 30.09647
# Epoch 1439, Loss 30.30554
# Epoch 1440, Loss 35.30909
# Epoch 1441, Loss 26.98371
# Epoch 1442, Loss 31.51785
# Epoch 1443, Loss 36.62498
# Epoch 1444, Loss 28.71792
# Epoch 1445, Loss 53.99744
# Epoch 1446, Loss 30.53785
# Epoch 1447, Loss 41.55081
# Epoch 1448, Loss 30.65847
# Epoch 1449, Loss 25.99716
# Epoch 1450, Loss 37.77163
# Epoch 1451, Loss 30.00851
# Epoch 1452, Loss 32.18575
# Epoch 1453, Loss 32.09458
# Epoch 1454, Loss 30.02515
# Epoch 1455, Loss 38.54747
# Epoch 1456, Loss 27.50732
# Epoch 1457, Loss 27.25902
# Epoch 1458, Loss 35.45282
# Epoch 1459, Loss 38.04038
# Epoch 1460, Loss 24.59215
# Epoch 1461, Loss 39.19391
# Epoch 1462, Loss 31.52316
# Epoch 1463, Loss 31.22191
# Epoch 1464, Loss 31.02906
# Epoch 1465, Loss 31.61586
# Epoch 1466, Loss 23.83838
# Epoch 1467, Loss 22.74351
# Epoch 1468, Loss 26.25768
# Epoch 1469, Loss 30.27262
# Epoch 1470, Loss 41.35726
# Epoch 1471, Loss 25.09129
# Epoch 1472, Loss 33.17798
# Epoch 1473, Loss 27.95206
# Epoch 1474, Loss 34.94773
# Epoch 1475, Loss 28.33624
# Epoch 1476, Loss 40.09884
# Epoch 1477, Loss 29.21256
# Epoch 1478, Loss 32.87138
# Epoch 1479, Loss 30.09544
# Epoch 1480, Loss 28.43763
# Epoch 1481, Loss 29.29377
# Epoch 1482, Loss 29.87296
# Epoch 1483, Loss 31.34550
# Epoch 1484, Loss 29.02282
# Epoch 1485, Loss 36.69303
# Epoch 1486, Loss 30.74553
# Epoch 1487, Loss 32.21063
# Epoch 1488, Loss 32.32788
# Epoch 1489, Loss 27.29345
# Epoch 1490, Loss 27.79315
# Epoch 1491, Loss 34.60678
# Epoch 1492, Loss 29.71460
# Epoch 1493, Loss 39.42605
# Epoch 1494, Loss 28.28119
# Epoch 1495, Loss 44.02418
# Epoch 1496, Loss 28.03078
# Epoch 1497, Loss 28.82233
# Epoch 1498, Loss 19.45443
# Epoch 1499, Loss 39.87916
# Epoch 1500, Loss 29.54097
# Epoch 1501, Loss 23.83521
# Epoch 1502, Loss 26.50322
# Epoch 1503, Loss 23.81324
# Epoch 1504, Loss 24.10907
# Epoch 1505, Loss 27.14906
# Epoch 1506, Loss 35.08106
# Epoch 1507, Loss 38.59995
# Epoch 1508, Loss 29.38342
# Epoch 1509, Loss 26.80911
# Epoch 1510, Loss 28.60425
# Epoch 1511, Loss 28.72778
# Epoch 1512, Loss 23.88272
# Epoch 1513, Loss 28.85547
# Epoch 1514, Loss 25.65179
# Epoch 1515, Loss 25.48323
# Epoch 1516, Loss 26.81977
# Epoch 1517, Loss 22.43739
# Epoch 1518, Loss 38.61969
# Epoch 1519, Loss 32.39811
# Epoch 1520, Loss 25.44063
# Epoch 1521, Loss 26.87403
# Epoch 1522, Loss 23.71519
# Epoch 1523, Loss 28.76381
# Epoch 1524, Loss 26.48587
# Epoch 1525, Loss 35.08773
# Epoch 1526, Loss 26.03391
# Epoch 1527, Loss 36.80310
# Epoch 1528, Loss 33.55848
# Epoch 1529, Loss 25.87996
# Epoch 1530, Loss 38.77591
# Epoch 1531, Loss 34.05958
# Epoch 1532, Loss 35.46798
# Epoch 1533, Loss 32.42484
# Epoch 1534, Loss 33.94446
# Epoch 1535, Loss 29.09497
# Epoch 1536, Loss 31.37458
# Epoch 1537, Loss 28.65066
# Epoch 1538, Loss 30.77787
# Epoch 1539, Loss 34.15801
# Epoch 1540, Loss 28.54176
# Epoch 1541, Loss 27.65426
# Epoch 1542, Loss 38.11052
# Epoch 1543, Loss 31.99482
# Epoch 1544, Loss 27.07874
# Epoch 1545, Loss 25.23207
# Epoch 1546, Loss 29.94133
# Epoch 1547, Loss 38.40289
# Epoch 1548, Loss 29.43273
# Epoch 1549, Loss 30.10978
# Epoch 1550, Loss 41.51219
# Epoch 1551, Loss 33.44098
# Epoch 1552, Loss 25.28324
# Epoch 1553, Loss 25.52334
# Epoch 1554, Loss 22.05338
# Epoch 1555, Loss 30.51616
# Epoch 1556, Loss 24.54019
# Epoch 1557, Loss 29.90023
# Epoch 1558, Loss 31.59614
# Epoch 1559, Loss 23.76311
# Epoch 1560, Loss 39.18875
# Epoch 1561, Loss 31.50475
# Epoch 1562, Loss 29.77053
# Epoch 1563, Loss 26.85680
# Epoch 1564, Loss 31.23538
# Epoch 1565, Loss 33.73456
# Epoch 1566, Loss 28.96894
# Epoch 1567, Loss 25.29102
# Epoch 1568, Loss 30.72524
# Epoch 1569, Loss 24.06171
# Epoch 1570, Loss 28.06804
# Epoch 1571, Loss 27.10573
# Epoch 1572, Loss 24.65275
# Epoch 1573, Loss 30.71677
# Epoch 1574, Loss 20.06946
# Epoch 1575, Loss 34.15371
# Epoch 1576, Loss 20.54334
# Epoch 1577, Loss 23.33264
# Epoch 1578, Loss 27.48212
# Epoch 1579, Loss 37.31877
# Epoch 1580, Loss 26.76247
# Epoch 1581, Loss 23.86728
# Epoch 1582, Loss 31.81645
# Epoch 1583, Loss 22.90708
# Epoch 1584, Loss 30.62460
# Epoch 1585, Loss 25.63338
# Epoch 1586, Loss 30.96871
# Epoch 1587, Loss 23.21402
# Epoch 1588, Loss 23.38634
# Epoch 1589, Loss 18.63032
# Epoch 1590, Loss 24.63803
# Epoch 1591, Loss 32.98421
# Epoch 1592, Loss 23.59222
# Epoch 1593, Loss 27.22592
# Epoch 1594, Loss 30.11360
# Epoch 1595, Loss 29.14198
# Epoch 1596, Loss 36.22115
# Epoch 1597, Loss 21.22761
# Epoch 1598, Loss 20.94096
# Epoch 1599, Loss 28.20854
# Epoch 1600, Loss 40.33165
# Epoch 1601, Loss 31.70802
# Epoch 1602, Loss 25.51359
# Epoch 1603, Loss 20.73200
# Epoch 1604, Loss 32.17537
# Epoch 1605, Loss 26.54019
# Epoch 1606, Loss 29.27932
# Epoch 1607, Loss 31.97577
# Epoch 1608, Loss 27.14889
# Epoch 1609, Loss 25.16460
# Epoch 1610, Loss 26.88915
# Epoch 1611, Loss 24.46885
# Epoch 1612, Loss 20.14210
# Epoch 1613, Loss 36.26676
# Epoch 1614, Loss 27.78583
# Epoch 1615, Loss 28.56604
# Epoch 1616, Loss 21.65791
# Epoch 1617, Loss 35.34414
# Epoch 1618, Loss 31.41915
# Epoch 1619, Loss 21.89247
# Epoch 1620, Loss 22.02334
# Epoch 1621, Loss 24.47534
# Epoch 1622, Loss 27.16812
# Epoch 1623, Loss 26.20641
# Epoch 1624, Loss 27.11415
# Epoch 1625, Loss 26.32806
# Epoch 1626, Loss 20.31690
# Epoch 1627, Loss 23.47633
# Epoch 1628, Loss 31.25321
# Epoch 1629, Loss 17.67691
# Epoch 1630, Loss 29.29339
# Epoch 1631, Loss 31.84735
# Epoch 1632, Loss 22.96051
# Epoch 1633, Loss 33.41342
# Epoch 1634, Loss 28.39334
# Epoch 1635, Loss 24.21085
# Epoch 1636, Loss 27.92140
# Epoch 1637, Loss 22.18260
# Epoch 1638, Loss 29.02031
# Epoch 1639, Loss 21.55321
# Epoch 1640, Loss 35.81154
# Epoch 1641, Loss 27.70245
# Epoch 1642, Loss 25.41865
# Epoch 1643, Loss 25.54537
# Epoch 1644, Loss 23.84377
# Epoch 1645, Loss 23.74511
# Epoch 1646, Loss 20.64337
# Epoch 1647, Loss 31.61784
# Epoch 1648, Loss 24.32474
# Epoch 1649, Loss 30.37563
# Epoch 1650, Loss 25.94563
# Epoch 1651, Loss 27.51044
# Epoch 1652, Loss 28.35428
# Epoch 1653, Loss 26.67681
# Epoch 1654, Loss 33.71267
# Epoch 1655, Loss 29.98130
# Epoch 1656, Loss 31.59866
# Epoch 1657, Loss 26.90872
# Epoch 1658, Loss 22.19397
# Epoch 1659, Loss 29.16537
# Epoch 1660, Loss 26.46047
# Epoch 1661, Loss 29.45472
# Epoch 1662, Loss 28.32687
# Epoch 1663, Loss 27.23465
# Epoch 1664, Loss 35.92378
# Epoch 1665, Loss 24.97125
# Epoch 1666, Loss 30.45922
# Epoch 1667, Loss 29.16489
# Epoch 1668, Loss 25.00382
# Epoch 1669, Loss 32.38788
# Epoch 1670, Loss 27.60413
# Epoch 1671, Loss 24.11191
# Epoch 1672, Loss 27.32776
# Epoch 1673, Loss 39.04614
# Epoch 1674, Loss 25.42995
# Epoch 1675, Loss 27.50732
# Epoch 1676, Loss 21.35600
# Epoch 1677, Loss 24.39249
# Epoch 1678, Loss 26.21435
# Epoch 1679, Loss 25.03855
# Epoch 1680, Loss 19.82092
# Epoch 1681, Loss 26.43628
# Epoch 1682, Loss 25.21859
# Epoch 1683, Loss 30.75535
# Epoch 1684, Loss 25.01390
# Epoch 1685, Loss 37.81801
# Epoch 1686, Loss 26.66254
# Epoch 1687, Loss 34.72813
# Epoch 1688, Loss 24.86966
# Epoch 1689, Loss 28.74339
# Epoch 1690, Loss 20.17982
# Epoch 1691, Loss 25.27317
# Epoch 1692, Loss 27.36568
# Epoch 1693, Loss 35.56218
# Epoch 1694, Loss 27.84614
# Epoch 1695, Loss 29.00197
# Epoch 1696, Loss 23.93435
# Epoch 1697, Loss 27.29195
# Epoch 1698, Loss 22.35297
# Epoch 1699, Loss 35.73991
# Epoch 1700, Loss 22.76988
# Epoch 1701, Loss 32.31272
# Epoch 1702, Loss 32.61311
# Epoch 1703, Loss 23.10963
# Epoch 1704, Loss 23.31201
# Epoch 1705, Loss 22.76315
# Epoch 1706, Loss 26.74603
# Epoch 1707, Loss 25.79398
# Epoch 1708, Loss 27.61907
# Epoch 1709, Loss 22.28108
# Epoch 1710, Loss 20.99327
# Epoch 1711, Loss 23.16182
# Epoch 1712, Loss 27.38315
# Epoch 1713, Loss 24.55358
# Epoch 1714, Loss 21.05000
# Epoch 1715, Loss 27.18238
# Epoch 1716, Loss 23.12942
# Epoch 1717, Loss 28.16688
# Epoch 1718, Loss 27.45111
# Epoch 1719, Loss 29.57928
# Epoch 1720, Loss 27.62589
# Epoch 1721, Loss 25.03618
# Epoch 1722, Loss 24.72707
# Epoch 1723, Loss 34.78061
# Epoch 1724, Loss 23.66466
# Epoch 1725, Loss 26.94768
# Epoch 1726, Loss 20.28385
# Epoch 1727, Loss 26.85411
# Epoch 1728, Loss 24.54274
# Epoch 1729, Loss 28.14191
# Epoch 1730, Loss 23.54851
# Epoch 1731, Loss 33.37977
# Epoch 1732, Loss 26.36958
# Epoch 1733, Loss 22.26569
# Epoch 1734, Loss 34.31561
# Epoch 1735, Loss 21.75649
# Epoch 1736, Loss 25.71036
# Epoch 1737, Loss 26.43648
# Epoch 1738, Loss 27.06553
# Epoch 1739, Loss 29.71230
# Epoch 1740, Loss 33.59939
# Epoch 1741, Loss 25.89089
# Epoch 1742, Loss 21.00137
# Epoch 1743, Loss 30.09066
# Epoch 1744, Loss 24.15513
# Epoch 1745, Loss 26.43763
# Epoch 1746, Loss 24.21298
# Epoch 1747, Loss 29.22844
# Epoch 1748, Loss 21.58177
# Epoch 1749, Loss 24.28204
# Epoch 1750, Loss 26.67936
# Epoch 1751, Loss 25.18341
# Epoch 1752, Loss 25.53404
# Epoch 1753, Loss 28.54799
# Epoch 1754, Loss 21.72781
# Epoch 1755, Loss 33.33337
# Epoch 1756, Loss 25.44542
# Epoch 1757, Loss 26.04180
# Epoch 1758, Loss 31.42342
# Epoch 1759, Loss 27.46887
# Epoch 1760, Loss 26.29284
# Epoch 1761, Loss 35.63327
# Epoch 1762, Loss 20.59200
# Epoch 1763, Loss 32.53518
# Epoch 1764, Loss 24.98198
# Epoch 1765, Loss 16.86162
# Epoch 1766, Loss 30.90199
# Epoch 1767, Loss 24.60429
# Epoch 1768, Loss 25.27587
# Epoch 1769, Loss 25.17840
# Epoch 1770, Loss 17.69418
# Epoch 1771, Loss 20.57249
# Epoch 1772, Loss 19.29018
# Epoch 1773, Loss 20.89711
# Epoch 1774, Loss 20.35603
# Epoch 1775, Loss 23.71554
# Epoch 1776, Loss 24.77274
# Epoch 1777, Loss 27.44881
# Epoch 1778, Loss 22.22716
# Epoch 1779, Loss 21.94432
# Epoch 1780, Loss 15.67936
# Epoch 1781, Loss 25.11847
# Epoch 1782, Loss 27.99568
# Epoch 1783, Loss 36.74161
# Epoch 1784, Loss 19.80651
# Epoch 1785, Loss 25.03256
# Epoch 1786, Loss 26.25921
# Epoch 1787, Loss 27.41211
# Epoch 1788, Loss 26.11009
# Epoch 1789, Loss 26.03316
# Epoch 1790, Loss 18.80974
# Epoch 1791, Loss 18.25960
# Epoch 1792, Loss 29.91966
# Epoch 1793, Loss 25.96612
# Epoch 1794, Loss 20.46932
# Epoch 1795, Loss 25.67235
# Epoch 1796, Loss 39.98152
# Epoch 1797, Loss 20.36406
# Epoch 1798, Loss 24.33299
# Epoch 1799, Loss 28.64303
# Epoch 1800, Loss 27.46049
# Epoch 1801, Loss 27.78223
# Epoch 1802, Loss 23.82399
# Epoch 1803, Loss 24.72376
# Epoch 1804, Loss 23.68738
# Epoch 1805, Loss 22.55124
# Epoch 1806, Loss 23.01781
# Epoch 1807, Loss 27.78507
# Epoch 1808, Loss 24.33337
# Epoch 1809, Loss 24.54123
# Epoch 1810, Loss 27.51993
# Epoch 1811, Loss 28.42978
# Epoch 1812, Loss 26.81279
# Epoch 1813, Loss 29.32697
# Epoch 1814, Loss 32.59753
# Epoch 1815, Loss 27.32947
# Epoch 1816, Loss 22.00063
# Epoch 1817, Loss 21.18890
# Epoch 1818, Loss 21.84871
# Epoch 1819, Loss 22.73932
# Epoch 1820, Loss 29.55089
# Epoch 1821, Loss 25.82732
# Epoch 1822, Loss 20.02095
# Epoch 1823, Loss 20.06751
# Epoch 1824, Loss 27.30173
# Epoch 1825, Loss 22.88695
# Epoch 1826, Loss 30.88922
# Epoch 1827, Loss 23.71704
# Epoch 1828, Loss 22.99154
# Epoch 1829, Loss 18.44735
# Epoch 1830, Loss 21.52504
# Epoch 1831, Loss 27.45469
# Epoch 1832, Loss 21.01361
# Epoch 1833, Loss 24.11035
# Epoch 1834, Loss 24.53674
# Epoch 1835, Loss 22.58762
# Epoch 1836, Loss 21.39315
# Epoch 1837, Loss 22.32313
# Epoch 1838, Loss 24.13448
# Epoch 1839, Loss 22.09410
# Epoch 1840, Loss 21.87319
# Epoch 1841, Loss 28.53569
# Epoch 1842, Loss 20.96652
# Epoch 1843, Loss 23.54146
# Epoch 1844, Loss 24.70956
# Epoch 1845, Loss 17.33062
# Epoch 1846, Loss 32.83468
# Epoch 1847, Loss 19.58748
# Epoch 1848, Loss 31.70974
# Epoch 1849, Loss 23.35416
# Epoch 1850, Loss 18.11118
# Epoch 1851, Loss 21.68974
# Epoch 1852, Loss 23.31070
# Epoch 1853, Loss 30.21340
# Epoch 1854, Loss 27.11196
# Epoch 1855, Loss 23.71235
# Epoch 1856, Loss 23.31937
# Epoch 1857, Loss 22.10098
# Epoch 1858, Loss 19.56156
# Epoch 1859, Loss 26.22694
# Epoch 1860, Loss 20.88984
# Epoch 1861, Loss 23.36179
# Epoch 1862, Loss 22.55736
# Epoch 1863, Loss 28.06031
# Epoch 1864, Loss 25.92589
# Epoch 1865, Loss 26.03362
# Epoch 1866, Loss 22.93653
# Epoch 1867, Loss 19.48594
# Epoch 1868, Loss 32.53083
# Epoch 1869, Loss 19.38517
# Epoch 1870, Loss 30.31124
# Epoch 1871, Loss 22.36412
# Epoch 1872, Loss 18.26989
# Epoch 1873, Loss 30.24089
# Epoch 1874, Loss 21.24657
# Epoch 1875, Loss 20.06150
# Epoch 1876, Loss 14.90580
# Epoch 1877, Loss 26.65972
# Epoch 1878, Loss 18.51907
# Epoch 1879, Loss 30.27640
# Epoch 1880, Loss 23.37807
# Epoch 1881, Loss 20.59095
# Epoch 1882, Loss 18.60223
# Epoch 1883, Loss 25.75677
# ...
# Epoch 2386, Loss 21.80510
# Epoch 2387, Loss 20.22157
# Epoch 2388, Loss 18.23696
# Epoch 2389, Loss 19.49002
# Epoch 2390, Loss 16.01393
# Epoch 2391, Loss 15.84244
# Epoch 2392, Loss 21.35048
# Epoch 2393, Loss 18.64571
# Epoch 2394, Loss 17.63939
# Epoch 2395, Loss 16.53376
# Epoch 2396, Loss 20.23818
# Epoch 2397, Loss 15.84028
# Epoch 2398, Loss 15.75223
# Epoch 2399, Loss 18.85898
# Epoch 2400, Loss 16.21910
# Epoch 2401, Loss 20.09683
# Epoch 2402, Loss 17.41239
# Epoch 2403, Loss 16.29535
# Epoch 2404, Loss 20.01591
# Epoch 2405, Loss 20.58124
# Epoch 2406, Loss 18.81159
# Epoch 2407, Loss 17.41584
# Epoch 2408, Loss 20.31720
# Epoch 2409, Loss 19.29880
# Epoch 2410, Loss 17.89697
# Epoch 2411, Loss 23.77201
# Epoch 2412, Loss 19.06870
# Epoch 2413, Loss 15.25415
# Epoch 2414, Loss 14.36399
# Epoch 2415, Loss 15.80742
# Epoch 2416, Loss 19.32957
# Epoch 2417, Loss 20.76714
# Epoch 2418, Loss 18.70894
# Epoch 2419, Loss 21.59959
# Epoch 2420, Loss 20.68593
# Epoch 2421, Loss 15.25126
# Epoch 2422, Loss 20.52110
# Epoch 2423, Loss 17.81879
# Epoch 2424, Loss 17.24462
# Epoch 2425, Loss 18.69993
# Epoch 2426, Loss 17.19920
# Epoch 2427, Loss 21.30806
# Epoch 2428, Loss 20.76561
# Epoch 2429, Loss 13.88445
# Epoch 2430, Loss 22.21295
# Epoch 2431, Loss 18.06809
# Epoch 2432, Loss 20.75084
# Epoch 2433, Loss 16.81596
# Epoch 2434, Loss 14.39203
# Epoch 2435, Loss 17.65928
# Epoch 2436, Loss 20.45062
# Epoch 2437, Loss 16.36686
# Epoch 2438, Loss 14.69300
# Epoch 2439, Loss 15.33139
# Epoch 2440, Loss 17.98561
# Epoch 2441, Loss 15.68600
# Epoch 2442, Loss 14.28890
# Epoch 2443, Loss 15.91237
# Epoch 2444, Loss 15.90474
# Epoch 2445, Loss 17.14697
# Epoch 2446, Loss 15.63818
# Epoch 2447, Loss 17.98724
# Epoch 2448, Loss 18.55066
# Epoch 2449, Loss 17.00114
# Epoch 2450, Loss 20.09149
# Epoch 2451, Loss 13.74582
# Epoch 2452, Loss 19.91163
# Epoch 2453, Loss 19.20889
# Epoch 2454, Loss 18.53682
# Epoch 2455, Loss 17.70646
# Epoch 2456, Loss 21.31265
# Epoch 2457, Loss 20.23121
# Epoch 2458, Loss 21.57111
# Epoch 2459, Loss 15.13055
# Epoch 2460, Loss 17.98362
# Epoch 2461, Loss 17.84043
# Epoch 2462, Loss 18.82458
# Epoch 2463, Loss 17.66827
# Epoch 2464, Loss 17.55684
# Epoch 2465, Loss 20.20115
# Epoch 2466, Loss 18.73377
# Epoch 2467, Loss 17.66805
# Epoch 2468, Loss 15.68551
# Epoch 2469, Loss 15.71595
# Epoch 2470, Loss 23.40313
# Epoch 2471, Loss 14.05191
# Epoch 2472, Loss 16.14822
# Epoch 2473, Loss 19.06246
# Epoch 2474, Loss 17.26187
# Epoch 2475, Loss 18.01053
# Epoch 2476, Loss 18.47345
# Epoch 2477, Loss 21.13439
# Epoch 2478, Loss 20.67468
# Epoch 2479, Loss 15.52467
# Epoch 2480, Loss 16.87832
# Epoch 2481, Loss 15.54940
# Epoch 2482, Loss 16.81650
# Epoch 2483, Loss 16.79199
# Epoch 2484, Loss 16.92143
# Epoch 2485, Loss 22.13087
# Epoch 2486, Loss 22.41974
# Epoch 2487, Loss 17.87970
# Epoch 2488, Loss 17.31819
# Epoch 2489, Loss 14.83381
# Epoch 2490, Loss 13.96238
# Epoch 2491, Loss 16.19513
# Epoch 2492, Loss 19.13885
# Epoch 2493, Loss 20.04566
# Epoch 2494, Loss 19.46011
# Epoch 2495, Loss 20.44149
# Epoch 2496, Loss 18.70190
# Epoch 2497, Loss 19.09004
# Epoch 2498, Loss 21.77158
# Epoch 2499, Loss 18.57768
# Epoch 2500, Loss 15.28748
# Epoch 2501, Loss 19.52534
# Epoch 2502, Loss 14.87038
# Epoch 2503, Loss 17.43869
# Epoch 2504, Loss 17.53531
# Epoch 2505, Loss 17.90831
# Epoch 2506, Loss 21.90207
# Epoch 2507, Loss 19.64931
# Epoch 2508, Loss 16.83626
# Epoch 2509, Loss 17.78754
# Epoch 2510, Loss 15.44871
# Epoch 2511, Loss 17.61505
# Epoch 2512, Loss 15.89540
# Epoch 2513, Loss 19.30975
# Epoch 2514, Loss 13.94947
# Epoch 2515, Loss 19.95643
# Epoch 2516, Loss 16.77221
# Epoch 2517, Loss 17.55241
# Epoch 2518, Loss 15.36712
# Epoch 2519, Loss 14.97516
# Epoch 2520, Loss 18.26715
# Epoch 2521, Loss 16.30316
# Epoch 2522, Loss 16.03262
# Epoch 2523, Loss 18.00897
# Epoch 2524, Loss 13.63654
# Epoch 2525, Loss 19.38285
# Epoch 2526, Loss 17.95322
# Epoch 2527, Loss 17.43190
# Epoch 2528, Loss 15.53127
# Epoch 2529, Loss 18.59110
# Epoch 2530, Loss 15.29144
# Epoch 2531, Loss 20.52940
# Epoch 2532, Loss 19.15485
# Epoch 2533, Loss 18.81019
# Epoch 2534, Loss 15.83017
# Epoch 2535, Loss 13.22910
# Epoch 2536, Loss 18.09867
# Epoch 2537, Loss 18.19633
# Epoch 2538, Loss 19.02708
# Epoch 2539, Loss 18.19323
# Epoch 2540, Loss 18.20332
# Epoch 2541, Loss 15.22419
# Epoch 2542, Loss 15.30225
# Epoch 2543, Loss 15.64318
# Epoch 2544, Loss 17.90101
# Epoch 2545, Loss 17.27324
# Epoch 2546, Loss 20.60955
# Epoch 2547, Loss 16.68546
# Epoch 2548, Loss 16.02481
# Epoch 2549, Loss 13.98287
# Epoch 2550, Loss 17.34065
# Epoch 2551, Loss 14.53681
# Epoch 2552, Loss 19.20902
# Epoch 2553, Loss 20.49114
# Epoch 2554, Loss 16.20128
# Epoch 2555, Loss 17.01577
# Epoch 2556, Loss 18.70228
# Epoch 2557, Loss 17.43889
# Epoch 2558, Loss 15.15245
# Epoch 2559, Loss 23.36224
# Epoch 2560, Loss 19.90592
# Epoch 2561, Loss 16.78458
# Epoch 2562, Loss 17.13406
# Epoch 2563, Loss 18.29008
# Epoch 2564, Loss 20.60953
# Epoch 2565, Loss 13.31732
# Epoch 2566, Loss 16.05733
# Epoch 2567, Loss 17.75680
# Epoch 2568, Loss 16.06234
# Epoch 2569, Loss 16.71739
# Epoch 2570, Loss 16.29338
# Epoch 2571, Loss 16.29262
# Epoch 2572, Loss 16.26880
# Epoch 2573, Loss 12.75212
# Epoch 2574, Loss 14.07329
# Epoch 2575, Loss 17.65168
# Epoch 2576, Loss 13.10437
# Epoch 2577, Loss 12.53445
# Epoch 2578, Loss 15.65154
# Epoch 2579, Loss 18.91723
# Epoch 2580, Loss 20.75665
# Epoch 2581, Loss 19.11550
# Epoch 2582, Loss 17.26646
# Epoch 2583, Loss 16.11222
# Epoch 2584, Loss 18.30265
# Epoch 2585, Loss 18.15421
# Epoch 2586, Loss 19.56458
# Epoch 2587, Loss 14.83864
# Epoch 2588, Loss 15.08845
# Epoch 2589, Loss 17.36518
# Epoch 2590, Loss 18.33783
# Epoch 2591, Loss 14.82924
# Epoch 2592, Loss 12.69973
# Epoch 2593, Loss 12.56498
# Epoch 2594, Loss 14.44093
# Epoch 2595, Loss 15.72170
# Epoch 2596, Loss 15.58619
# Epoch 2597, Loss 16.60029
# Epoch 2598, Loss 14.86929
# Epoch 2599, Loss 17.66260
# Epoch 2600, Loss 15.28291
# Epoch 2601, Loss 14.60816
# Epoch 2602, Loss 13.69568
# Epoch 2603, Loss 17.54961
# Epoch 2604, Loss 17.01299
# Epoch 2605, Loss 18.27401
# Epoch 2606, Loss 16.34672
# Epoch 2607, Loss 16.12244
# Epoch 2608, Loss 20.07538
# Epoch 2609, Loss 19.59662
# Epoch 2610, Loss 15.96342
# Epoch 2611, Loss 16.55791
# Epoch 2612, Loss 16.07840
# Epoch 2613, Loss 17.55604
# Epoch 2614, Loss 17.33034
# Epoch 2615, Loss 16.83630
# Epoch 2616, Loss 17.27954
# Epoch 2617, Loss 14.09353
# Epoch 2618, Loss 20.17630
# Epoch 2619, Loss 12.94698
# Epoch 2620, Loss 17.84252
# Epoch 2621, Loss 13.11135
# Epoch 2622, Loss 13.32458
# Epoch 2623, Loss 16.67735
# Epoch 2624, Loss 16.26698
# Epoch 2625, Loss 11.78766
# Epoch 2626, Loss 15.95627
# Epoch 2627, Loss 17.46105
# Epoch 2628, Loss 17.67722
# Epoch 2629, Loss 15.51319
# Epoch 2630, Loss 19.08464
# Epoch 2631, Loss 17.65485
# Epoch 2632, Loss 13.96887
# Epoch 2633, Loss 17.14416
# Epoch 2634, Loss 18.02321
# Epoch 2635, Loss 16.02633
# Epoch 2636, Loss 16.95741
# Epoch 2637, Loss 15.25587
# Epoch 2638, Loss 14.71471
# Epoch 2639, Loss 17.10152
# Epoch 2640, Loss 14.97974
# Epoch 2641, Loss 15.19801
# Epoch 2642, Loss 16.44648
# Epoch 2643, Loss 17.20939
# Epoch 2644, Loss 16.43993
# Epoch 2645, Loss 16.29674
# Epoch 2646, Loss 19.09119
# Epoch 2647, Loss 17.16932
# Epoch 2648, Loss 15.27237
# Epoch 2649, Loss 16.02342
# Epoch 2650, Loss 16.05055
# Epoch 2651, Loss 16.60580
# Epoch 2652, Loss 15.70280
# Epoch 2653, Loss 15.78618
# Epoch 2654, Loss 13.31274
# Epoch 2655, Loss 13.22096
# Epoch 2656, Loss 14.70564
# Epoch 2657, Loss 18.52709
# Epoch 2658, Loss 13.67334
# Epoch 2659, Loss 13.28829
# Epoch 2660, Loss 19.29663
# Epoch 2661, Loss 14.79337
# Epoch 2662, Loss 13.55746
# Epoch 2663, Loss 18.74576
# Epoch 2664, Loss 16.58369
# Epoch 2665, Loss 21.00655
# Epoch 2666, Loss 17.93385
# Epoch 2667, Loss 14.38050
# Epoch 2668, Loss 13.02642
# Epoch 2669, Loss 16.30415
# Epoch 2670, Loss 16.73719
# Epoch 2671, Loss 19.24581
# Epoch 2672, Loss 14.63695
# Epoch 2673, Loss 15.45237
# Epoch 2674, Loss 18.63048
# Epoch 2675, Loss 19.58202
# Epoch 2676, Loss 16.22342
# Epoch 2677, Loss 17.18844
# Epoch 2678, Loss 18.47766
# Epoch 2679, Loss 16.25738
# Epoch 2680, Loss 19.56227
# Epoch 2681, Loss 13.47045
# Epoch 2682, Loss 15.28899
# Epoch 2683, Loss 14.27016
# Epoch 2684, Loss 13.79717
# Epoch 2685, Loss 17.06484
# Epoch 2686, Loss 14.44412
# Epoch 2687, Loss 19.21150
# Epoch 2688, Loss 16.35643
# Epoch 2689, Loss 18.02174
# Epoch 2690, Loss 16.67646
# Epoch 2691, Loss 16.08361
# Epoch 2692, Loss 19.40463
# Epoch 2693, Loss 14.68679
# Epoch 2694, Loss 14.78727
# Epoch 2695, Loss 17.50605
# Epoch 2696, Loss 13.90172
# Epoch 2697, Loss 20.10934
# Epoch 2698, Loss 15.53673
# Epoch 2699, Loss 18.93212
# Epoch 2700, Loss 15.09076
# Epoch 2701, Loss 16.19026
# Epoch 2702, Loss 19.70979
# Epoch 2703, Loss 17.47827
# Epoch 2704, Loss 17.42144
# Epoch 2705, Loss 14.34166
# Epoch 2706, Loss 15.33330
# Epoch 2707, Loss 16.76726
# Epoch 2708, Loss 14.74985
# Epoch 2709, Loss 18.06006
# Epoch 2710, Loss 19.03620
# Epoch 2711, Loss 15.11612
# Epoch 2712, Loss 15.10487
# Epoch 2713, Loss 17.70292
# Epoch 2714, Loss 13.82603
# Epoch 2715, Loss 12.83185
# Epoch 2716, Loss 15.81206
# Epoch 2717, Loss 15.92654
# Epoch 2718, Loss 13.38227
# Epoch 2719, Loss 19.71019
# Epoch 2720, Loss 18.96806
# Epoch 2721, Loss 16.45125
# Epoch 2722, Loss 16.19402
# Epoch 2723, Loss 19.27048
# Epoch 2724, Loss 15.64849
# Epoch 2725, Loss 18.12559
# Epoch 2726, Loss 16.56920
# Epoch 2727, Loss 15.59165
# Epoch 2728, Loss 16.74325
# Epoch 2729, Loss 16.33205
# Epoch 2730, Loss 15.81488
# Epoch 2731, Loss 14.31545
# Epoch 2732, Loss 13.83665
# Epoch 2733, Loss 14.23024
# Epoch 2734, Loss 18.03977
# Epoch 2735, Loss 16.68275
# Epoch 2736, Loss 15.44490
# Epoch 2737, Loss 12.22417
# Epoch 2738, Loss 12.81161
# Epoch 2739, Loss 14.72569
# Epoch 2740, Loss 14.68406
# Epoch 2741, Loss 15.73083
# Epoch 2742, Loss 17.87665
# Epoch 2743, Loss 12.98260
# Epoch 2744, Loss 15.15048
# Epoch 2745, Loss 15.00639
# Epoch 2746, Loss 15.10712
# Epoch 2747, Loss 15.43582
# Epoch 2748, Loss 12.71003
# Epoch 2749, Loss 18.83958
# Epoch 2750, Loss 15.22155
# Epoch 2751, Loss 17.38258
# Epoch 2752, Loss 16.99052
# Epoch 2753, Loss 19.47153
# Epoch 2754, Loss 15.01663
# Epoch 2755, Loss 20.87099
# Epoch 2756, Loss 14.30446
# Epoch 2757, Loss 17.63479
# Epoch 2758, Loss 18.93368
# Epoch 2759, Loss 18.07194
# Epoch 2760, Loss 20.27856
# Epoch 2761, Loss 13.17639
# Epoch 2762, Loss 14.82622
# Epoch 2763, Loss 15.78048
# Epoch 2764, Loss 16.17550
# Epoch 2765, Loss 15.81361
# Epoch 2766, Loss 16.05961
# Epoch 2767, Loss 14.94620
# Epoch 2768, Loss 17.06406
# Epoch 2769, Loss 14.48204
# Epoch 2770, Loss 14.65169
# Epoch 2771, Loss 13.21567
# Epoch 2772, Loss 17.50357
# Epoch 2773, Loss 14.75200
# Epoch 2774, Loss 17.16684
# Epoch 2775, Loss 14.16353
# Epoch 2776, Loss 14.57981
# Epoch 2777, Loss 17.94015
# Epoch 2778, Loss 17.83237
# Epoch 2779, Loss 16.12282
# Epoch 2780, Loss 16.62726
# Epoch 2781, Loss 14.80791
# Epoch 2782, Loss 16.17374
# Epoch 2783, Loss 15.26079
# Epoch 2784, Loss 18.49875
# Epoch 2785, Loss 23.10573
# Epoch 2786, Loss 15.55976
# Epoch 2787, Loss 14.09049
# Epoch 2788, Loss 16.23351
# Epoch 2789, Loss 13.44238
# Epoch 2790, Loss 15.77069
# Epoch 2791, Loss 13.67596
# Epoch 2792, Loss 13.53402
# Epoch 2793, Loss 15.54493
# Epoch 2794, Loss 16.23822
# Epoch 2795, Loss 14.35394
# Epoch 2796, Loss 13.70498
# Epoch 2797, Loss 18.55901
# Epoch 2798, Loss 17.58660
# Epoch 2799, Loss 16.26368
# Epoch 2800, Loss 13.27016
# Epoch 2801, Loss 16.92587
# Epoch 2802, Loss 18.17724
# Epoch 2803, Loss 14.26580
# Epoch 2804, Loss 15.82307
# Epoch 2805, Loss 19.25915
# Epoch 2806, Loss 13.64536
# Epoch 2807, Loss 15.70862
# Epoch 2808, Loss 16.96362
# Epoch 2809, Loss 15.59558
# Epoch 2810, Loss 16.98970
# Epoch 2811, Loss 14.80820
# Epoch 2812, Loss 16.10239
# Epoch 2813, Loss 17.45401
# Epoch 2814, Loss 14.68548
# Epoch 2815, Loss 14.95720
# Epoch 2816, Loss 14.32426
# Epoch 2817, Loss 18.37791
# Epoch 2818, Loss 17.40607
# Epoch 2819, Loss 15.81676
# Epoch 2820, Loss 15.68035
# Epoch 2821, Loss 14.87694
# Epoch 2822, Loss 14.31483
# Epoch 2823, Loss 14.91629
# Epoch 2824, Loss 17.98127
# Epoch 2825, Loss 13.29693
# Epoch 2826, Loss 16.76726
# Epoch 2827, Loss 13.24396
# Epoch 2828, Loss 15.21151
# Epoch 2829, Loss 14.04904
# Epoch 2830, Loss 12.51661
# Epoch 2831, Loss 16.45422
# Epoch 2832, Loss 20.11014
# Epoch 2833, Loss 16.19792
# Epoch 2834, Loss 15.42216
# Epoch 2835, Loss 13.54500
# Epoch 2836, Loss 14.31711
# Epoch 2837, Loss 14.14615
# Epoch 2838, Loss 14.61203
# Epoch 2839, Loss 16.41873
# Epoch 2840, Loss 15.68710
# Epoch 2841, Loss 14.19973
# Epoch 2842, Loss 16.28776
# Epoch 2843, Loss 17.66934
# Epoch 2844, Loss 16.82291
# Epoch 2845, Loss 13.20891
# Epoch 2846, Loss 14.63148
# Epoch 2847, Loss 16.81604
# Epoch 2848, Loss 13.35543
# Epoch 2849, Loss 14.76299
# Epoch 2850, Loss 13.01256
# Epoch 2851, Loss 16.88832
# Epoch 2852, Loss 15.50923
# Epoch 2853, Loss 15.76074
# Epoch 2854, Loss 18.02065
# Epoch 2855, Loss 14.76525
# Epoch 2856, Loss 16.42915
# Epoch 2857, Loss 12.32617
# Epoch 2858, Loss 14.72772
# Epoch 2859, Loss 16.43717
# Epoch 2860, Loss 13.24778
# Epoch 2861, Loss 14.81027
# Epoch 2862, Loss 15.52442
# Epoch 2863, Loss 17.07498
# Epoch 2864, Loss 18.35443
# Epoch 2865, Loss 16.51333
# Epoch 2866, Loss 16.25056
# Epoch 2867, Loss 16.38035
# Epoch 2868, Loss 16.78431
# Epoch 2869, Loss 12.82155
# Epoch 2870, Loss 17.33870
# Epoch 2871, Loss 17.94237
# Epoch 2872, Loss 12.64860
# Epoch 2873, Loss 15.52666
# Epoch 2874, Loss 14.87797
# Epoch 2875, Loss 16.22942
# Epoch 2876, Loss 13.65036
# Epoch 2877, Loss 17.31858
# Epoch 2878, Loss 15.60902
# Epoch 2879, Loss 13.80884
# Epoch 2880, Loss 16.64451
# Epoch 2881, Loss 15.32270
# Epoch 2882, Loss 14.24842
# Epoch 2883, Loss 14.13478
# Epoch 2884, Loss 16.69299
# Epoch 2885, Loss 13.10535
# Epoch 2886, Loss 16.94990
# Epoch 2887, Loss 17.71858
# Epoch 2888, Loss 13.80815
# Epoch 2889, Loss 13.58666
# Epoch 2890, Loss 13.32104
# Epoch 2891, Loss 14.94710
# Epoch 2892, Loss 16.90533
# Epoch 2893, Loss 15.69573
# Epoch 2894, Loss 15.33325
# Epoch 2895, Loss 17.77803
# Epoch 2896, Loss 16.47044
# Epoch 2897, Loss 13.29509
# Epoch 2898, Loss 16.31994
# Epoch 2899, Loss 15.79342
# Epoch 2900, Loss 13.98823
# Epoch 2901, Loss 15.78995
# Epoch 2902, Loss 18.18260
# Epoch 2903, Loss 14.84668
# Epoch 2904, Loss 14.94324
# Epoch 2905, Loss 16.16247
# Epoch 2906, Loss 15.23436
# Epoch 2907, Loss 15.28753
# Epoch 2908, Loss 14.44376
# Epoch 2909, Loss 17.22193
# Epoch 2910, Loss 15.17279
# Epoch 2911, Loss 18.19094
# Epoch 2912, Loss 13.87167
# Epoch 2913, Loss 15.03920
# Epoch 2914, Loss 15.19822
# Epoch 2915, Loss 15.82434
# Epoch 2916, Loss 13.92460
# Epoch 2917, Loss 16.13342
# Epoch 2918, Loss 15.52137
# Epoch 2919, Loss 17.85309
# Epoch 2920, Loss 14.36023
# Epoch 2921, Loss 14.46354
# Epoch 2922, Loss 15.16094
# Epoch 2923, Loss 16.14605
# Epoch 2924, Loss 16.52968
# Epoch 2925, Loss 13.37199
# Epoch 2926, Loss 15.62853
# Epoch 2927, Loss 15.56861
# Epoch 2928, Loss 13.60150
# Epoch 2929, Loss 13.46677
# Epoch 2930, Loss 15.74380
# Epoch 2931, Loss 15.10192
# Epoch 2932, Loss 15.32026
# Epoch 2933, Loss 15.39799
# Epoch 2934, Loss 15.20609
# Epoch 2935, Loss 13.08024
# Epoch 2936, Loss 14.49347
# Epoch 2937, Loss 13.81164
# Epoch 2938, Loss 16.43692
# Epoch 2939, Loss 15.62139
# Epoch 2940, Loss 13.00265
# Epoch 2941, Loss 15.80426
# Epoch 2942, Loss 16.51159
# Epoch 2943, Loss 14.34349
# Epoch 2944, Loss 14.72484
# Epoch 2945, Loss 16.27969
# Epoch 2946, Loss 12.81653
# Epoch 2947, Loss 16.77687
# Epoch 2948, Loss 16.95412
# Epoch 2949, Loss 16.93855
# Epoch 2950, Loss 14.88827
# Epoch 2951, Loss 13.25361
# Epoch 2952, Loss 12.81208
# Epoch 2953, Loss 17.35537
# Epoch 2954, Loss 14.66269
# Epoch 2955, Loss 14.98334
# Epoch 2956, Loss 15.08406
# Epoch 2957, Loss 15.86941
# Epoch 2958, Loss 12.50461
# Epoch 2959, Loss 16.41782
# Epoch 2960, Loss 13.57605
# Epoch 2961, Loss 17.56998
# Epoch 2962, Loss 11.91579
# Epoch 2963, Loss 15.53196
# Epoch 2964, Loss 16.18329
# Epoch 2965, Loss 14.95832
# Epoch 2966, Loss 13.56984
# Epoch 2967, Loss 17.06431
# Epoch 2968, Loss 16.17397
# Epoch 2969, Loss 15.31219
# Epoch 2970, Loss 16.29837
# Epoch 2971, Loss 11.67309
# Epoch 2972, Loss 16.79331
# Epoch 2973, Loss 14.45286
# Epoch 2974, Loss 13.11166
# Epoch 2975, Loss 13.85085
# Epoch 2976, Loss 11.85747
# Epoch 2977, Loss 16.21714
# Epoch 2978, Loss 15.75446
# Epoch 2979, Loss 15.74644
# Epoch 2980, Loss 17.94955
# Epoch 2981, Loss 16.15133
# Epoch 2982, Loss 15.37498
# Epoch 2983, Loss 13.91526
# Epoch 2984, Loss 14.59226
# Epoch 2985, Loss 12.47686
# Epoch 2986, Loss 16.54068
# Epoch 2987, Loss 12.86105
# Epoch 2988, Loss 15.99317
# Epoch 2989, Loss 13.84834
# Epoch 2990, Loss 12.70763
# Epoch 2991, Loss 16.88304
# Epoch 2992, Loss 14.40010
# Epoch 2993, Loss 14.66249
# Epoch 2994, Loss 14.16774
# Epoch 2995, Loss 12.59529
# Epoch 2996, Loss 12.01514
# Epoch 2997, Loss 16.44652
# Epoch 2998, Loss 15.20228
# Epoch 2999, Loss 12.10847
# Epoch 3000, Loss 14.15721

# %%
# plot data
plt.figure(figsize=(10, 3))
plt.subplot(1, 3, 1)
plt.plot(t_span, y_mean, linestyle='--', c='k', alpha=.7)
plt.scatter(t, y)
plt.title('Training data')
plt.ylim([0, 1.5])
plt.xlabel("time")
plt.ylabel('y(t)')

plt.subplot(1, 3, 2)
plt.plot(t_span, y_mean, linestyle='--', c='k', alpha=.7)
for _ in range(15):
    
    # random sample
    z = np.random.randn(M)
    w = T(z, theta)
    
    # sim model 
    y_sim = model_tspan(x0, t_span, w)
    plt.plot(t_span, y_sim, c='C0', alpha=.5)
plt.title('Model fit')
plt.xlabel("time")
plt.ylim([0, 1.5])

# plot params
plt.subplot(1, 3, 3)
xp, yp = np.linspace(0, 2, 100), np.linspace(0, 2, 100)
X, Y = np.meshgrid(xp, yp)
pos = np.dstack((X, Y))

# unpack params
m, s = theta
cov = np.diag(np.exp(s))
rv = multivariate_normal(m, cov)
Z = rv.pdf(pos)
plt.contour(X, Y, Z, levels=5, cmap='viridis', zorder=0)
plt.xlabel("Growth rate")
plt.ylabel("Carrying capacity")
plt.title("Parameter estimate")
plt.scatter([1.],[1.],label='True', zorder=1)
plt.legend()

plt.tight_layout()
plt.show()
